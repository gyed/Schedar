# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Subset, DataLoader
from torchvision import datasets, transforms
import random
import time
import sys

sys.path.append("..")
from utils.tool import GPU_info, write_log, print_label_stat
from models.resnet import ResNet8, ResNet18, ResNet50
from models.mobilenet import MobileNet_S, MobileNet_M, MobileNet_L
from framework.ours import Device
from framework.DSGD import DSGD_Device
from framework.SISA import SISA_Device
from framework.FedAvgUnl import FedAvgServer, FedAvgClient


# one in ['ours', 'DSGD', 'SISA', 'Fed']
Framework = 'DSGD'

# one in ['MNIST', 'FMNIST', 'CIFAR10']
DatasetName = 'CIFAR10'

# one in ['resnet', 'mobilenet']
ModelType = 'mobilenet'

# one in [1,0]. 1 - Heterogeneous;  0 - Homogeneous
Heterogeneous = 1

# %%
train_set_o = None
test_set_o = None
num_classes = 10
device_num = 5
num_channel = 1
ref_size = 10000
train_test_total_size = int(50000/device_num)
test_ratio = 0.2

train_batch_size = 256 if ModelType == 'resnet' else 32
save_path = './checkpoint'
data_path = '../data'
log_path = '../log/unlearn_{}_{}_{}.txt'.format(Framework, ModelType, DatasetName)

my_seed = 1
torch.cuda.manual_seed(my_seed)

if DatasetName == 'CIFAR10':
    train_set_o = datasets.CIFAR10(data_path, train=True, download=True)
    test_set_o = datasets.CIFAR10(data_path, train=False, download=True)
    num_channel = 3

elif DatasetName == 'MNIST':    
    train_set_o = datasets.MNIST(data_path, train=True, download=True)
    test_set_o = datasets.MNIST(data_path, train=False, download=True)

elif DatasetName == 'FMNIST':    
    train_set_o = datasets.FashionMNIST(data_path, train=True, download=True)
    test_set_o = datasets.FashionMNIST(data_path, train=False, download=True)

train_set_o.transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,)),
])

test_set_o.transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,)),
])

ref_set = Subset(test_set_o, range(0,int(ref_size)))
ref_loader = torch.utils.data.DataLoader(ref_set, batch_size=train_batch_size,
                                         shuffle=False, num_workers=0)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# data manipulation
device_dict = {}
loader_dict = {}
print('Device', end='\t')
for class_id in range(num_classes):
    print('Class'+str(class_id), end='\t')
print('SUM')
for device_id in range(device_num):
    range_start = train_test_total_size * device_id
    range_end = range_start + train_test_total_size
    # remove one class from each local dataset
    class_to_remove = torch.tensor(device_id%10)
    indices = (torch.tensor(train_set_o.targets[range_start:range_end])[..., None] !=
               class_to_remove).any(-1).nonzero(as_tuple=True)[0]
    # split train&test
    train_test_border = int((1-test_ratio)*len(indices))
    train_set = Subset(train_set_o, indices[:train_test_border]+range_start)
    test_set = Subset(train_set_o, indices[train_test_border:]+range_start)
    train_loader = DataLoader(train_set, batch_size=train_batch_size,
                              shuffle=True, num_workers=0)
    test_loader = DataLoader(test_set, batch_size=train_batch_size,
                             shuffle=True, num_workers=0) 
    loader_dict[device_id] = [train_loader, test_loader]
    print_label_stat(device_id, train_set, num_classes)
    
    
# initialize devices
for device_id in range(device_num):
    gpu_id = 0
    device_dict[device_id] = DSGD_Device(device_id, gpu_id, num_classes, num_channel)
# Out:
# Device	Class0	Class1	Class2	Class3	Class4	Class5	Class6	Class7	Class8	Class9	SUM
# D-0	0	764	817	807	806	765	830	809	807	791	7196
# D-1	793	0	817	806	802	768	813	824	782	789	7194
# D-2	798	807	0	817	790	815	787	806	781	827	7228
# D-3	790	770	852	0	809	824	803	781	802	788	7219
# D-4	822	816	770	806	0	831	778	778	788	813	7202

# %%
if Heterogeneous == 1:
    # heterogeneous scenario
    write_log(log_path, 'heterogeneous')
    for device_id in range(device_num):
        gpu_id = 0
        device_dict[device_id].model = ResNet8(num_channel) if ModelType == 'resnet' else MobileNet_S(num_channel)
        device_dict[device_id].model.cuda(gpu_id)
        device_dict[device_id].optimizer = optim.Adam(device_dict[device_id].model.parameters(), lr=0.01)
else:
    # homogeneous scenario
    write_log(log_path, 'homogeneous')
    for device_id in range(device_num):
        gpu_id = 0
        device_dict[device_id].model = ResNet50(num_channel) if ModelType == 'resnet' else MobileNet_L(num_channel)
        device_dict[device_id].model.cuda(gpu_id)
        device_dict[device_id].optimizer = optim.Adam(device_dict[device_id].model.parameters(), lr=0.01)

# %%
print(device_dict.keys())
# Out:
# dict_keys([0, 1, 2, 3, 4])

# %%
# remove one client for rejoin
device_back_up = device_dict[4]
print(device_dict.keys())
del device_dict[4]
print(device_dict.keys())

# assign neighbors
for k, v in device_dict.items():
    # full neighbor list
    neighbor_list = [x for x in device_dict.keys() if x != k]  
    v.neighbor_list = neighbor_list
# Out:
# dict_keys([0, 1, 2, 3, 4])
# dict_keys([0, 1, 2, 3])

# %%
# train models
epoch_num = 800 if ModelType == 'resnet' else 200
write_log(log_path, time.ctime(time.time()))
for epoch in range(epoch_num):
    for device_id, device in device_dict.items():
        device.train_local_model(num_iter=1, local_loader=loader_dict[device_id][0])
        device.communication(frac=1, gamma=0.9, device_dict=device_dict)
    metric = []
    for device_id, device in device_dict.items():
        metric.append(device.validate_local_model(test_loader=loader_dict[device_id][1]))
    metric_arr=np.array(metric)
    log_txt = '{:.4f}\t{:.4f}\t{:.4f}\t{:.4f}'.format(np.mean(metric_arr, axis=0)[0], 
                                      np.mean(metric_arr, axis=0)[1],np.mean(metric_arr, axis=0)[2],
                                      np.mean(metric_arr, axis=0)[3])
    print('Epoch: {}  mean: {}'.format(epoch, log_txt), end='\n\n')
    write_log(log_path, log_txt)
# Out:
# Client 0	Epoch:  0		Loss: 1.74429679
# Client 1	Epoch:  0		Loss: 1.46573496
# Client 2	Epoch:  0		Loss: 1.78396702
# Client 3	Epoch:  0		Loss: 1.84331954
# Server - Avg_loss: 0.0773, Acc: 209.0/1799 (0.1162)
# Server - Avg_loss: 0.0722, Acc: 193.0/1799 (0.1073)
# Server - Avg_loss: 0.0752, Acc: 200.0/1807 (0.1107)
# Server - Avg_loss: 0.0707, Acc: 200.0/1805 (0.1108)
# Epoch: 0  mean: 0.1112	0.0127	0.1108	0.0223
#
# Client 0	Epoch:  0		Loss: 1.71681404
# Client 1	Epoch:  0		Loss: 1.47704315
# Client 2	Epoch:  0		Loss: 1.80626774
# Client 3	Epoch:  0		Loss: 1.49480391
# Server - Avg_loss: 0.0789, Acc: 223.0/1799 (0.1240)
# Server - Avg_loss: 0.0738, Acc: 193.0/1799 (0.1073)
# Server - Avg_loss: 0.0820, Acc: 200.0/1807 (0.1107)
# Server - Avg_loss: 0.0723, Acc: 197.0/1805 (0.1091)
# Epoch: 1  mean: 0.1128	0.0184	0.1135	0.0256
#
# Client 0	Epoch:  0		Loss: 1.55770123
# Client 1	Epoch:  0		Loss: 1.41021097
# Client 2	Epoch:  0		Loss: 2.10281253
# Client 3	Epoch:  0		Loss: 1.81956327
# Server - Avg_loss: 0.0826, Acc: 219.0/1799 (0.1217)
# Server - Avg_loss: 0.0743, Acc: 237.0/1799 (0.1317)
# Server - Avg_loss: 0.0849, Acc: 200.0/1807 (0.1107)
# Server - Avg_loss: 0.0725, Acc: 195.0/1805 (0.1080)
# Epoch: 2  mean: 0.1180	0.0215	0.1169	0.0303
#
# Client 0	Epoch:  0		Loss: 1.44388425
# Client 1	Epoch:  0		Loss: 1.56400108
# Client 2	Epoch:  0		Loss: 1.30227411
# Client 3	Epoch:  0		Loss: 1.52176189
# Server - Avg_loss: 0.0842, Acc: 224.0/1799 (0.1245)
# Server - Avg_loss: 0.0778, Acc: 193.0/1799 (0.1073)
# Server - Avg_loss: 0.0872, Acc: 226.0/1807 (0.1251)
# Server - Avg_loss: 0.0732, Acc: 201.0/1805 (0.1114)
# Epoch: 3  mean: 0.1171	0.0231	0.1171	0.0319
#
# Client 0	Epoch:  0		Loss: 1.33568537
# Client 1	Epoch:  0		Loss: 1.08888948
# Client 2	Epoch:  0		Loss: 1.48136640
# Client 3	Epoch:  0		Loss: 1.45047498
# Server - Avg_loss: 0.0934, Acc: 209.0/1799 (0.1162)
# Server - Avg_loss: 0.0841, Acc: 261.0/1799 (0.1451)
# Server - Avg_loss: 0.0971, Acc: 191.0/1807 (0.1057)
# Server - Avg_loss: 0.0785, Acc: 263.0/1805 (0.1457)
# Epoch: 4  mean: 0.1282	0.0290	0.1260	0.0378
#
# Client 0	Epoch:  0		Loss: 1.21464264
# Client 1	Epoch:  0		Loss: 1.52379811
# Client 2	Epoch:  0		Loss: 1.06142914
# Client 3	Epoch:  0		Loss: 1.24161851
# Server - Avg_loss: 0.0975, Acc: 222.0/1799 (0.1234)
# Server - Avg_loss: 0.0834, Acc: 206.0/1799 (0.1145)
# Server - Avg_loss: 0.1008, Acc: 191.0/1807 (0.1057)
# Server - Avg_loss: 0.0901, Acc: 193.0/1805 (0.1069)
# Epoch: 5  mean: 0.1126	0.0233	0.1134	0.0303
#
# Client 0	Epoch:  0		Loss: 1.40860963
# Client 1	Epoch:  0		Loss: 1.16355133
# Client 2	Epoch:  0		Loss: 1.37186849
# Client 3	Epoch:  0		Loss: 1.29865170
# Server - Avg_loss: 0.1000, Acc: 209.0/1799 (0.1162)
# Server - Avg_loss: 0.0856, Acc: 247.0/1799 (0.1373)
# Server - Avg_loss: 0.0926, Acc: 196.0/1807 (0.1085)
# Server - Avg_loss: 0.0842, Acc: 201.0/1805 (0.1114)
# Epoch: 6  mean: 0.1183	0.0317	0.1194	0.0370
#
# Client 0	Epoch:  0		Loss: 1.38896084
# Client 1	Epoch:  0		Loss: 1.30134225
# Client 2	Epoch:  0		Loss: 1.51096117
# Client 3	Epoch:  0		Loss: 1.29018557
# Server - Avg_loss: 0.1007, Acc: 200.0/1799 (0.1112)
# Server - Avg_loss: 0.0744, Acc: 257.0/1799 (0.1429)
# Server - Avg_loss: 0.0968, Acc: 206.0/1807 (0.1140)
# Server - Avg_loss: 0.0830, Acc: 201.0/1805 (0.1114)
# Epoch: 7  mean: 0.1198	0.0360	0.1230	0.0374
#
# Client 0	Epoch:  0		Loss: 1.55118537
# Client 1	Epoch:  0		Loss: 1.30013299
# Client 2	Epoch:  0		Loss: 1.18494952
# Client 3	Epoch:  0		Loss: 1.56352043
# Server - Avg_loss: 0.1094, Acc: 256.0/1799 (0.1423)
# Server - Avg_loss: 0.0838, Acc: 360.0/1799 (0.2001)
# Server - Avg_loss: 0.0994, Acc: 239.0/1807 (0.1323)
# Server - Avg_loss: 0.0859, Acc: 207.0/1805 (0.1147)
# Epoch: 8  mean: 0.1473	0.0551	0.1505	0.0645
#
# Client 0	Epoch:  0		Loss: 1.37607980
# Client 1	Epoch:  0		Loss: 1.70325065
# Client 2	Epoch:  0		Loss: 1.25530088
# Client 3	Epoch:  0		Loss: 1.24972641
# Server - Avg_loss: 0.1036, Acc: 292.0/1799 (0.1623)
# Server - Avg_loss: 0.0897, Acc: 242.0/1799 (0.1345)
# Server - Avg_loss: 0.1012, Acc: 209.0/1807 (0.1157)
# Server - Avg_loss: 0.1122, Acc: 201.0/1805 (0.1114)
# Epoch: 9  mean: 0.1310	0.0370	0.1324	0.0443
#
# Client 0	Epoch:  0		Loss: 1.34572399
# Client 1	Epoch:  0		Loss: 1.14255571
# Client 2	Epoch:  0		Loss: 1.29601014
# Client 3	Epoch:  0		Loss: 1.38444507
# Server - Avg_loss: 0.1202, Acc: 219.0/1799 (0.1217)
# Server - Avg_loss: 0.0925, Acc: 252.0/1799 (0.1401)
# Server - Avg_loss: 0.1128, Acc: 211.0/1807 (0.1168)
# Server - Avg_loss: 0.1198, Acc: 201.0/1805 (0.1114)
# Epoch: 10  mean: 0.1225	0.0302	0.1248	0.0358
#
# Client 0	Epoch:  0		Loss: 1.48958790
# Client 1	Epoch:  0		Loss: 1.31793427
# Client 2	Epoch:  0		Loss: 1.18137443
# Client 3	Epoch:  0		Loss: 1.38875294
# Server - Avg_loss: 0.1017, Acc: 303.0/1799 (0.1684)
# Server - Avg_loss: 0.0846, Acc: 267.0/1799 (0.1484)
# Server - Avg_loss: 0.1245, Acc: 192.0/1807 (0.1063)
# Server - Avg_loss: 0.1218, Acc: 201.0/1805 (0.1114)
# Epoch: 11  mean: 0.1336	0.0362	0.1324	0.0453
#
# Client 0	Epoch:  0		Loss: 1.48184240
# Client 1	Epoch:  0		Loss: 1.10214508
# Client 2	Epoch:  0		Loss: 1.69849372
# Client 3	Epoch:  0		Loss: 1.01931834
# Server - Avg_loss: 0.1079, Acc: 252.0/1799 (0.1401)
# Server - Avg_loss: 0.0897, Acc: 240.0/1799 (0.1334)
# Server - Avg_loss: 0.1462, Acc: 191.0/1807 (0.1057)
# Server - Avg_loss: 0.1312, Acc: 201.0/1805 (0.1114)
# Epoch: 12  mean: 0.1226	0.0326	0.1235	0.0382
#
# Client 0	Epoch:  0		Loss: 1.01630723
# Client 1	Epoch:  0		Loss: 1.05121672
# Client 2	Epoch:  0		Loss: 1.27451205
# Client 3	Epoch:  0		Loss: 1.31994259
# Server - Avg_loss: 0.1001, Acc: 223.0/1799 (0.1240)
# Server - Avg_loss: 0.0868, Acc: 254.0/1799 (0.1412)
# Server - Avg_loss: 0.1141, Acc: 209.0/1807 (0.1157)
# Server - Avg_loss: 0.1223, Acc: 210.0/1805 (0.1163)
# Epoch: 13  mean: 0.1243	0.0389	0.1241	0.0377
#
# Client 0	Epoch:  0		Loss: 1.19431746
# Client 1	Epoch:  0		Loss: 1.04915786
# Client 2	Epoch:  0		Loss: 1.12583542
# Client 3	Epoch:  0		Loss: 1.17228949
# Server - Avg_loss: 0.1182, Acc: 229.0/1799 (0.1273)
# Server - Avg_loss: 0.0902, Acc: 266.0/1799 (0.1479)
# Server - Avg_loss: 0.1519, Acc: 192.0/1807 (0.1063)
# Server - Avg_loss: 0.1439, Acc: 209.0/1805 (0.1158)
# Epoch: 14  mean: 0.1243	0.0313	0.1297	0.0378
#
# Client 0	Epoch:  0		Loss: 1.23832321
# Client 1	Epoch:  0		Loss: 1.25114119
# Client 2	Epoch:  0		Loss: 1.17578399
# Client 3	Epoch:  0		Loss: 1.14664149
# Server - Avg_loss: 0.0972, Acc: 299.0/1799 (0.1662)
# Server - Avg_loss: 0.0965, Acc: 247.0/1799 (0.1373)
# Server - Avg_loss: 0.1628, Acc: 191.0/1807 (0.1057)
# Server - Avg_loss: 0.1262, Acc: 220.0/1805 (0.1219)
# Epoch: 15  mean: 0.1328	0.0386	0.1345	0.0461
#
# Client 0	Epoch:  0		Loss: 1.12699759
# Client 1	Epoch:  0		Loss: 1.31003654
# Client 2	Epoch:  0		Loss: 1.15553248
# Client 3	Epoch:  0		Loss: 0.82985407
# Server - Avg_loss: 0.1063, Acc: 314.0/1799 (0.1745)
# Server - Avg_loss: 0.0883, Acc: 362.0/1799 (0.2012)
# Server - Avg_loss: 0.1687, Acc: 191.0/1807 (0.1057)
# Server - Avg_loss: 0.1251, Acc: 224.0/1805 (0.1241)
# Epoch: 16  mean: 0.1514	0.0509	0.1531	0.0593
#
# Client 0	Epoch:  0		Loss: 1.53316128
# Client 1	Epoch:  0		Loss: 1.34750628
# Client 2	Epoch:  0		Loss: 0.95173138
# Client 3	Epoch:  0		Loss: 0.84312207
# Server - Avg_loss: 0.0896, Acc: 348.0/1799 (0.1934)
# Server - Avg_loss: 0.0971, Acc: 236.0/1799 (0.1312)
# Server - Avg_loss: 0.1395, Acc: 202.0/1807 (0.1118)
# Server - Avg_loss: 0.1135, Acc: 257.0/1805 (0.1424)
# Epoch: 17  mean: 0.1447	0.0670	0.1438	0.0612
#
# Client 0	Epoch:  0		Loss: 1.30487180
# Client 1	Epoch:  0		Loss: 0.96982408
# Client 2	Epoch:  0		Loss: 1.24611962
# Client 3	Epoch:  0		Loss: 1.09435415
# Server - Avg_loss: 0.1042, Acc: 285.0/1799 (0.1584)
# Server - Avg_loss: 0.0930, Acc: 285.0/1799 (0.1584)
# Server - Avg_loss: 0.1344, Acc: 192.0/1807 (0.1063)
# Server - Avg_loss: 0.1264, Acc: 235.0/1805 (0.1302)
# Epoch: 18  mean: 0.1383	0.0456	0.1396	0.0490
#
# Client 0	Epoch:  0		Loss: 1.18492222
# Client 1	Epoch:  0		Loss: 1.50724089
# Client 2	Epoch:  0		Loss: 1.08852065
# Client 3	Epoch:  0		Loss: 1.66538298
# Server - Avg_loss: 0.0981, Acc: 286.0/1799 (0.1590)
# Server - Avg_loss: 0.0899, Acc: 321.0/1799 (0.1784)
# Server - Avg_loss: 0.1322, Acc: 208.0/1807 (0.1151)
# Server - Avg_loss: 0.1022, Acc: 273.0/1805 (0.1512)
# Epoch: 19  mean: 0.1509	0.0935	0.1518	0.0781
#
# Client 0	Epoch:  0		Loss: 1.22677004
# Client 1	Epoch:  0		Loss: 1.25824845
# Client 2	Epoch:  0		Loss: 1.20030844
# Client 1	Epoch:  0		Loss: 1.24007630
# Client 2	Epoch:  0		Loss: 1.07309759
# Client 3	Epoch:  0		Loss: 1.08443010
# Server - Avg_loss: 0.0810, Acc: 492.0/1799 (0.2735)
# Server - Avg_loss: 0.0936, Acc: 278.0/1799 (0.1545)
# Server - Avg_loss: 0.1018, Acc: 308.0/1807 (0.1704)
# Server - Avg_loss: 0.0989, Acc: 381.0/1805 (0.2111)
# Epoch: 24  mean: 0.2024	0.1428	0.2017	0.1232
#
# Client 0	Epoch:  0		Loss: 1.18121791
# Client 1	Epoch:  0		Loss: 1.78685582
# Client 2	Epoch:  0		Loss: 0.97397178
# Client 3	Epoch:  0		Loss: 1.36177278
# Server - Avg_loss: 0.0769, Acc: 489.0/1799 (0.2718)
# Server - Avg_loss: 0.1010, Acc: 354.0/1799 (0.1968)
# Server - Avg_loss: 0.0925, Acc: 367.0/1807 (0.2031)
# Server - Avg_loss: 0.0892, Acc: 441.0/1805 (0.2443)
# Epoch: 25  mean: 0.2290	0.1639	0.2279	0.1458
#
# Client 0	Epoch:  0		Loss: 0.97621667
# Client 1	Epoch:  0		Loss: 1.51443303
# Client 2	Epoch:  0		Loss: 1.08268499
# Client 3	Epoch:  0		Loss: 0.91364431
# Server - Avg_loss: 0.0723, Acc: 517.0/1799 (0.2874)
# Server - Avg_loss: 0.0785, Acc: 465.0/1799 (0.2585)
# Server - Avg_loss: 0.1106, Acc: 322.0/1807 (0.1782)
# Server - Avg_loss: 0.0899, Acc: 407.0/1805 (0.2255)
# Epoch: 26  mean: 0.2374	0.1818	0.2380	0.1589
#
# Client 0	Epoch:  0		Loss: 0.84121972
# Client 1	Epoch:  0		Loss: 1.03208530
# Client 2	Epoch:  0		Loss: 1.11533380
# Client 3	Epoch:  0		Loss: 0.70763731
# Server - Avg_loss: 0.0708, Acc: 570.0/1799 (0.3168)
# Server - Avg_loss: 0.0912, Acc: 416.0/1799 (0.2312)
# Server - Avg_loss: 0.0714, Acc: 532.0/1807 (0.2944)
# Server - Avg_loss: 0.0788, Acc: 507.0/1805 (0.2809)
# Epoch: 27  mean: 0.2808	0.2236	0.2798	0.1976
#
# Client 0	Epoch:  0		Loss: 1.00660598
# Client 1	Epoch:  0		Loss: 1.38873792
# Client 2	Epoch:  0		Loss: 0.97121793
# Client 3	Epoch:  0		Loss: 1.09301519
# Server - Avg_loss: 0.0642, Acc: 643.0/1799 (0.3574)
# Server - Avg_loss: 0.0865, Acc: 392.0/1799 (0.2179)
# Server - Avg_loss: 0.0919, Acc: 344.0/1807 (0.1904)
# Server - Avg_loss: 0.0846, Acc: 463.0/1805 (0.2565)
# Epoch: 28  mean: 0.2556	0.2010	0.2567	0.1791
#
# Client 0	Epoch:  0		Loss: 1.38413739
# Client 1	Epoch:  0		Loss: 1.15841794
# Client 2	Epoch:  0		Loss: 0.82473147
# Client 3	Epoch:  0		Loss: 1.46533298
# Server - Avg_loss: 0.0679, Acc: 577.0/1799 (0.3207)
# Server - Avg_loss: 0.0886, Acc: 437.0/1799 (0.2429)
# Server - Avg_loss: 0.0752, Acc: 470.0/1807 (0.2601)
# Server - Avg_loss: 0.0937, Acc: 344.0/1805 (0.1906)
# Epoch: 29  mean: 0.2536	0.2234	0.2542	0.1786
#
# Client 0	Epoch:  0		Loss: 1.49306488
# Client 1	Epoch:  0		Loss: 1.13270891
# Client 2	Epoch:  0		Loss: 0.74580204
# Client 3	Epoch:  0		Loss: 1.09164202
# Server - Avg_loss: 0.0649, Acc: 615.0/1799 (0.3419)
# Server - Avg_loss: 0.0867, Acc: 423.0/1799 (0.2351)
# Server - Avg_loss: 0.0694, Acc: 557.0/1807 (0.3082)
# Server - Avg_loss: 0.0842, Acc: 391.0/1805 (0.2166)
# Epoch: 30  mean: 0.2755	0.2063	0.2703	0.1865
#
# Client 0	Epoch:  0		Loss: 1.13070905
# Client 1	Epoch:  0		Loss: 1.12813520
# Client 2	Epoch:  0		Loss: 1.36231041
# Client 3	Epoch:  0		Loss: 1.31203306
# Server - Avg_loss: 0.0664, Acc: 631.0/1799 (0.3508)
# Server - Avg_loss: 0.0846, Acc: 362.0/1799 (0.2012)
# Server - Avg_loss: 0.0783, Acc: 430.0/1807 (0.2380)
# Server - Avg_loss: 0.0735, Acc: 544.0/1805 (0.3014)
# Epoch: 31  mean: 0.2728	0.2130	0.2678	0.1862
#
# Client 0	Epoch:  0		Loss: 1.76400459
# Client 1	Epoch:  0		Loss: 1.03520763
# Client 2	Epoch:  0		Loss: 1.03758264
# Client 3	Epoch:  0		Loss: 1.46140313
# Server - Avg_loss: 0.0634, Acc: 584.0/1799 (0.3246)
# Server - Avg_loss: 0.1081, Acc: 243.0/1799 (0.1351)
# Server - Avg_loss: 0.0810, Acc: 402.0/1807 (0.2225)
# Server - Avg_loss: 0.0824, Acc: 430.0/1805 (0.2382)
# Epoch: 32  mean: 0.2301	0.1791	0.2319	0.1508
#
# Client 0	Epoch:  0		Loss: 1.37142146
# Client 1	Epoch:  0		Loss: 1.04855931
# Client 2	Epoch:  0		Loss: 1.04282987
# Client 3	Epoch:  0		Loss: 1.07999647
# Server - Avg_loss: 0.0641, Acc: 584.0/1799 (0.3246)
# Server - Avg_loss: 0.0885, Acc: 370.0/1799 (0.2057)
# Server - Avg_loss: 0.0774, Acc: 414.0/1807 (0.2291)
# Server - Avg_loss: 0.0845, Acc: 445.0/1805 (0.2465)
# Epoch: 33  mean: 0.2515	0.2154	0.2517	0.1761
#
# Client 0	Epoch:  0		Loss: 1.13161349
# Client 1	Epoch:  0		Loss: 0.73270363
# Client 2	Epoch:  0		Loss: 1.07342267
# Client 3	Epoch:  0		Loss: 1.27387500
# Server - Avg_loss: 0.0713, Acc: 504.0/1799 (0.2802)
# Server - Avg_loss: 0.0833, Acc: 391.0/1799 (0.2173)
# Server - Avg_loss: 0.0787, Acc: 423.0/1807 (0.2341)
# Server - Avg_loss: 0.0752, Acc: 502.0/1805 (0.2781)
# Epoch: 34  mean: 0.2524	0.2197	0.2544	0.1771
#
# Client 0	Epoch:  0		Loss: 0.92631400
# Client 1	Epoch:  0		Loss: 1.19837785
# Client 2	Epoch:  0		Loss: 1.13891852
# Client 3	Epoch:  0		Loss: 1.52109957
# Server - Avg_loss: 0.0576, Acc: 746.0/1799 (0.4147)
# Server - Avg_loss: 0.0804, Acc: 458.0/1799 (0.2546)
# Server - Avg_loss: 0.0792, Acc: 478.0/1807 (0.2645)
# Server - Avg_loss: 0.0738, Acc: 552.0/1805 (0.3058)
# Epoch: 35  mean: 0.3099	0.2331	0.3064	0.2131
#
# Client 0	Epoch:  0		Loss: 1.05244565
# Client 1	Epoch:  0		Loss: 1.38453817
# Client 2	Epoch:  0		Loss: 1.02965188
# Client 3	Epoch:  0		Loss: 1.30078518
# Server - Avg_loss: 0.0562, Acc: 778.0/1799 (0.4325)
# Server - Avg_loss: 0.0796, Acc: 437.0/1799 (0.2429)
# Server - Avg_loss: 0.0650, Acc: 581.0/1807 (0.3215)
# Server - Avg_loss: 0.0777, Acc: 543.0/1805 (0.3008)
# Epoch: 36  mean: 0.3244	0.2623	0.3242	0.2355
#
# Client 0	Epoch:  0		Loss: 1.09888375
# Client 1	Epoch:  0		Loss: 0.92834914
# Client 2	Epoch:  0		Loss: 1.02933419
# Client 3	Epoch:  0		Loss: 1.00168824
# Server - Avg_loss: 0.0560, Acc: 729.0/1799 (0.4052)
# Server - Avg_loss: 0.0709, Acc: 565.0/1799 (0.3141)
# Server - Avg_loss: 0.0590, Acc: 654.0/1807 (0.3619)
# Server - Avg_loss: 0.0644, Acc: 649.0/1805 (0.3596)
# Epoch: 37  mean: 0.3602	0.3025	0.3546	0.2663
#
# Client 0	Epoch:  0		Loss: 0.94630402
# Client 1	Epoch:  0		Loss: 1.26768768
# Client 2	Epoch:  0		Loss: 1.19398999
# Client 3	Epoch:  0		Loss: 0.92544383
# Server - Avg_loss: 0.0493, Acc: 841.0/1799 (0.4675)
# Server - Avg_loss: 0.0714, Acc: 568.0/1799 (0.3157)
# Server - Avg_loss: 0.0661, Acc: 585.0/1807 (0.3237)
# Server - Avg_loss: 0.0625, Acc: 709.0/1805 (0.3928)
# Epoch: 38  mean: 0.3749	0.3237	0.3747	0.2889
#
# Client 0	Epoch:  0		Loss: 0.70257533
# Client 1	Epoch:  0		Loss: 1.36624539
# Client 2	Epoch:  0		Loss: 0.81758457
# Client 3	Epoch:  0		Loss: 1.07576966
# Server - Avg_loss: 0.0528, Acc: 810.0/1799 (0.4503)
# Server - Avg_loss: 0.0750, Acc: 520.0/1799 (0.2890)
# Server - Avg_loss: 0.0662, Acc: 599.0/1807 (0.3315)
# Server - Avg_loss: 0.0690, Acc: 613.0/1805 (0.3396)
# Epoch: 39  mean: 0.3526	0.3098	0.3523	0.2708
#
# Client 0	Epoch:  0		Loss: 1.07218671
# Client 1	Epoch:  0		Loss: 0.98019063
# Client 2	Epoch:  0		Loss: 0.82939053
# Client 3	Epoch:  0		Loss: 1.21772301
# Server - Avg_loss: 0.0484, Acc: 870.0/1799 (0.4836)
# Server - Avg_loss: 0.0745, Acc: 472.0/1799 (0.2624)
# Server - Avg_loss: 0.0638, Acc: 583.0/1807 (0.3226)
# Server - Avg_loss: 0.0637, Acc: 661.0/1805 (0.3662)
# Epoch: 40  mean: 0.3587	0.3341	0.3557	0.2828
#
# Client 0	Epoch:  0		Loss: 1.35595953
# Client 1	Epoch:  0		Loss: 0.87136090
# Client 2	Epoch:  0		Loss: 0.83181506
# Client 3	Epoch:  0		Loss: 0.93206203
# Server - Avg_loss: 0.0479, Acc: 888.0/1799 (0.4936)
# Server - Avg_loss: 0.0660, Acc: 557.0/1799 (0.3096)
# Server - Avg_loss: 0.0659, Acc: 586.0/1807 (0.3243)
# Server - Avg_loss: 0.0598, Acc: 760.0/1805 (0.4211)
# Epoch: 41  mean: 0.3871	0.3695	0.3831	0.3116
#
# Client 0	Epoch:  0		Loss: 0.96804649
# Client 1	Epoch:  0		Loss: 1.01275754
# Client 2	Epoch:  0		Loss: 1.28654981
# Client 3	Epoch:  0		Loss: 1.55813229
# Server - Avg_loss: 0.0468, Acc: 882.0/1799 (0.4903)
# Server - Avg_loss: 0.0699, Acc: 531.0/1799 (0.2952)
# Server - Avg_loss: 0.0543, Acc: 759.0/1807 (0.4200)
# Server - Avg_loss: 0.0599, Acc: 738.0/1805 (0.4089)
# Epoch: 42  mean: 0.4036	0.3738	0.3951	0.3254
#
# Client 0	Epoch:  0		Loss: 0.91812611
# Client 1	Epoch:  0		Loss: 1.63351333
# Client 2	Epoch:  0		Loss: 1.12328959
# Client 3	Epoch:  0		Loss: 1.17981625
# Server - Avg_loss: 0.0448, Acc: 910.0/1799 (0.5058)
# Server - Avg_loss: 0.0549, Acc: 694.0/1799 (0.3858)
# Server - Avg_loss: 0.0547, Acc: 726.0/1807 (0.4018)
# Server - Avg_loss: 0.0560, Acc: 776.0/1805 (0.4299)
# Epoch: 43  mean: 0.4308	0.4118	0.4326	0.3572
#
# Client 0	Epoch:  0		Loss: 1.37735343
# Client 1	Epoch:  0		Loss: 0.85210127
# Client 2	Epoch:  0		Loss: 1.00514197
# Client 3	Epoch:  0		Loss: 1.02157950
# Server - Avg_loss: 0.0504, Acc: 856.0/1799 (0.4758)
# Server - Avg_loss: 0.0585, Acc: 662.0/1799 (0.3680)
# Server - Avg_loss: 0.0496, Acc: 827.0/1807 (0.4577)
# Server - Avg_loss: 0.0576, Acc: 754.0/1805 (0.4177)
# Epoch: 44  mean: 0.4298	0.3930	0.4203	0.3452
#
# Client 0	Epoch:  0		Loss: 1.03449845
# Client 1	Epoch:  0		Loss: 1.06047177
# Client 2	Epoch:  0		Loss: 0.70426273
# Client 3	Epoch:  0		Loss: 0.63453656
# Server - Avg_loss: 0.0415, Acc: 997.0/1799 (0.5542)
# Server - Avg_loss: 0.0599, Acc: 663.0/1799 (0.3685)
# Server - Avg_loss: 0.0506, Acc: 811.0/1807 (0.4488)
# Server - Avg_loss: 0.0581, Acc: 737.0/1805 (0.4083)
# Epoch: 45  mean: 0.4450	0.4318	0.4406	0.3729
#
# Client 0	Epoch:  0		Loss: 1.13861096
# Client 1	Epoch:  0		Loss: 1.50046670
# Client 2	Epoch:  0		Loss: 1.30286229
# Client 3	Epoch:  0		Loss: 1.12732995
# Server - Avg_loss: 0.0455, Acc: 913.0/1799 (0.5075)
# Server - Avg_loss: 0.0628, Acc: 617.0/1799 (0.3430)
# Server - Avg_loss: 0.0511, Acc: 805.0/1807 (0.4455)
# Server - Avg_loss: 0.0550, Acc: 764.0/1805 (0.4233)
# Epoch: 46  mean: 0.4298	0.4065	0.4302	0.3569
#
# Client 0	Epoch:  0		Loss: 0.97854775
# Client 1	Epoch:  0		Loss: 1.04529095
# Client 2	Epoch:  0		Loss: 1.01953161
# Client 3	Epoch:  0		Loss: 1.35413373
# Server - Avg_loss: 0.0468, Acc: 892.0/1799 (0.4958)
# Server - Avg_loss: 0.0565, Acc: 704.0/1799 (0.3913)
# Server - Avg_loss: 0.0437, Acc: 902.0/1807 (0.4992)
# Server - Avg_loss: 0.0601, Acc: 727.0/1805 (0.4028)
# Epoch: 47  mean: 0.4473	0.4027	0.4514	0.3663
#
# Client 0	Epoch:  0		Loss: 1.02488530
# Client 1	Epoch:  0		Loss: 0.86554456
# Client 2	Epoch:  0		Loss: 0.88581079
# Client 3	Epoch:  0		Loss: 1.13188970
# Server - Avg_loss: 0.0420, Acc: 951.0/1799 (0.5286)
# Server - Avg_loss: 0.0517, Acc: 756.0/1799 (0.4202)
# Server - Avg_loss: 0.0447, Acc: 904.0/1807 (0.5003)
# Server - Avg_loss: 0.0526, Acc: 832.0/1805 (0.4609)
# Epoch: 48  mean: 0.4775	0.4449	0.4646	0.3970
#
# Client 0	Epoch:  0		Loss: 1.06533277
# Client 1	Epoch:  0		Loss: 1.22477674
# Client 2	Epoch:  0		Loss: 1.01105571
# Client 3	Epoch:  0		Loss: 0.71740079
# Server - Avg_loss: 0.0452, Acc: 938.0/1799 (0.5214)
# Server - Avg_loss: 0.0552, Acc: 717.0/1799 (0.3986)
# Server - Avg_loss: 0.0426, Acc: 929.0/1807 (0.5141)
# Server - Avg_loss: 0.0514, Acc: 836.0/1805 (0.4632)
# Epoch: 49  mean: 0.4743	0.4285	0.4700	0.3910
#
# Client 0	Epoch:  0		Loss: 1.24233985
# Client 1	Epoch:  0		Loss: 0.94079548
# Client 2	Epoch:  0		Loss: 1.15971112
# Client 3	Epoch:  0		Loss: 0.79180646
# Server - Avg_loss: 0.0427, Acc: 960.0/1799 (0.5336)
# Server - Avg_loss: 0.0548, Acc: 745.0/1799 (0.4141)
# Server - Avg_loss: 0.0403, Acc: 970.0/1807 (0.5368)
# Server - Avg_loss: 0.0493, Acc: 879.0/1805 (0.4870)
# Epoch: 50  mean: 0.4929	0.4613	0.4903	0.4196
#
# Client 0	Epoch:  0		Loss: 0.95370245
# Client 1	Epoch:  0		Loss: 1.11466491
# Client 2	Epoch:  0		Loss: 1.20444787
# Client 3	Epoch:  0		Loss: 1.15042531
# Server - Avg_loss: 0.0413, Acc: 970.0/1799 (0.5392)
# Server - Avg_loss: 0.0527, Acc: 752.0/1799 (0.4180)
# Server - Avg_loss: 0.0449, Acc: 930.0/1807 (0.5147)
# Server - Avg_loss: 0.0496, Acc: 868.0/1805 (0.4809)
# Epoch: 51  mean: 0.4882	0.4546	0.4840	0.4079
#
# Client 0	Epoch:  0		Loss: 1.40091622
# Client 1	Epoch:  0		Loss: 0.97444987
# Client 2	Epoch:  0		Loss: 0.71734238
# Client 3	Epoch:  0		Loss: 0.94987416
# Server - Avg_loss: 0.0415, Acc: 1007.0/1799 (0.5598)
# Server - Avg_loss: 0.0516, Acc: 791.0/1799 (0.4397)
# Server - Avg_loss: 0.0382, Acc: 1016.0/1807 (0.5623)
# Server - Avg_loss: 0.0469, Acc: 896.0/1805 (0.4964)
# Epoch: 52  mean: 0.5145	0.4942	0.5092	0.4440
#
# Client 0	Epoch:  0		Loss: 0.92199022
# Client 1	Epoch:  0		Loss: 1.21717358
# Client 2	Epoch:  0		Loss: 1.25966465
# Client 3	Epoch:  0		Loss: 1.03924358
# Server - Avg_loss: 0.0397, Acc: 1009.0/1799 (0.5609)
# Server - Avg_loss: 0.0484, Acc: 824.0/1799 (0.4580)
# Server - Avg_loss: 0.0412, Acc: 987.0/1807 (0.5462)
# Server - Avg_loss: 0.0466, Acc: 874.0/1805 (0.4842)
# Epoch: 53  mean: 0.5123	0.5104	0.5036	0.4442
#
# Client 0	Epoch:  0		Loss: 0.78977352
# Client 1	Epoch:  0		Loss: 0.95875639
# Client 2	Epoch:  0		Loss: 0.73462212
# Client 3	Epoch:  0		Loss: 0.96382171
# Server - Avg_loss: 0.0396, Acc: 1005.0/1799 (0.5586)
# Server - Avg_loss: 0.0550, Acc: 773.0/1799 (0.4297)
# Server - Avg_loss: 0.0361, Acc: 1045.0/1807 (0.5783)
# Server - Avg_loss: 0.0443, Acc: 916.0/1805 (0.5075)
# Epoch: 54  mean: 0.5185	0.5078	0.5119	0.4524
#
# Client 0	Epoch:  0		Loss: 0.96290451
# Client 1	Epoch:  0		Loss: 0.95342851
# Client 2	Epoch:  0		Loss: 0.84944934
# Client 3	Epoch:  0		Loss: 1.27064931
# Server - Avg_loss: 0.0403, Acc: 993.0/1799 (0.5520)
# Server - Avg_loss: 0.0438, Acc: 903.0/1799 (0.5019)
# Server - Avg_loss: 0.0410, Acc: 946.0/1807 (0.5235)
# Server - Avg_loss: 0.0458, Acc: 904.0/1805 (0.5008)
# Epoch: 55  mean: 0.5196	0.5001	0.5088	0.4467
#
# Client 0	Epoch:  0		Loss: 1.04478562
# Client 1	Epoch:  0		Loss: 1.24637079
# Client 2	Epoch:  0		Loss: 0.98302895
# Client 3	Epoch:  0		Loss: 0.93799591
# Server - Avg_loss: 0.0386, Acc: 1015.0/1799 (0.5642)
# Server - Avg_loss: 0.0454, Acc: 901.0/1799 (0.5008)
# Server - Avg_loss: 0.0394, Acc: 1003.0/1807 (0.5551)
# Server - Avg_loss: 0.0403, Acc: 1008.0/1805 (0.5584)
# Epoch: 56  mean: 0.5446	0.5236	0.5372	0.4756
#
# Client 0	Epoch:  0		Loss: 0.97530258
# Client 1	Epoch:  0		Loss: 1.16741586
# Client 2	Epoch:  0		Loss: 0.95050794
# Client 3	Epoch:  0		Loss: 1.43629229
# Server - Avg_loss: 0.0455, Acc: 914.0/1799 (0.5081)
# Server - Avg_loss: 0.0439, Acc: 920.0/1799 (0.5114)
# Server - Avg_loss: 0.0374, Acc: 997.0/1807 (0.5517)
# Server - Avg_loss: 0.0457, Acc: 909.0/1805 (0.5036)
# Epoch: 57  mean: 0.5187	0.4883	0.5101	0.4410
#
# Client 0	Epoch:  0		Loss: 0.78000671
# Client 1	Epoch:  0		Loss: 1.02028501
# Client 2	Epoch:  0		Loss: 0.72131568
# Client 3	Epoch:  0		Loss: 1.86326921
# Server - Avg_loss: 0.0457, Acc: 913.0/1799 (0.5075)
# Server - Avg_loss: 0.0457, Acc: 891.0/1799 (0.4953)
# Server - Avg_loss: 0.0415, Acc: 973.0/1807 (0.5385)
# Server - Avg_loss: 0.0436, Acc: 954.0/1805 (0.5285)
# Epoch: 58  mean: 0.5174	0.4876	0.5167	0.4396
#
# Client 0	Epoch:  0		Loss: 0.89831918
# Client 1	Epoch:  0		Loss: 1.08288395
# Client 2	Epoch:  0		Loss: 1.55075264
# Client 3	Epoch:  0		Loss: 0.87678158
# Server - Avg_loss: 0.0412, Acc: 969.0/1799 (0.5386)
# Server - Avg_loss: 0.0431, Acc: 942.0/1799 (0.5236)
# Server - Avg_loss: 0.0376, Acc: 1012.0/1807 (0.5600)
# Server - Avg_loss: 0.0412, Acc: 1004.0/1805 (0.5562)
# Epoch: 59  mean: 0.5446	0.5153	0.5396	0.4681
#
# Client 0	Epoch:  0		Loss: 0.93699872
# Client 1	Epoch:  0		Loss: 0.98034036
# Client 2	Epoch:  0		Loss: 0.87903464
# Client 3	Epoch:  0		Loss: 0.56691450
# Server - Avg_loss: 0.0369, Acc: 1048.0/1799 (0.5825)
# Server - Avg_loss: 0.0426, Acc: 952.0/1799 (0.5292)
# Server - Avg_loss: 0.0386, Acc: 1004.0/1807 (0.5556)
# Server - Avg_loss: 0.0408, Acc: 973.0/1805 (0.5391)
# Epoch: 60  mean: 0.5516	0.5213	0.5466	0.4813
#
# Client 0	Epoch:  0		Loss: 0.82708156
# Client 1	Epoch:  0		Loss: 0.87312329
# Client 2	Epoch:  0		Loss: 1.11426008
# Client 3	Epoch:  0		Loss: 0.75002223
# Server - Avg_loss: 0.0412, Acc: 978.0/1799 (0.5436)
# Server - Avg_loss: 0.0437, Acc: 932.0/1799 (0.5181)
# Server - Avg_loss: 0.0432, Acc: 953.0/1807 (0.5274)
# Server - Avg_loss: 0.0402, Acc: 1009.0/1805 (0.5590)
# Epoch: 61  mean: 0.5370	0.5247	0.5267	0.4685
#
# Client 0	Epoch:  0		Loss: 0.71406847
# Client 1	Epoch:  0		Loss: 1.17554080
# Client 2	Epoch:  0		Loss: 0.85301769
# Client 3	Epoch:  0		Loss: 1.14122868
# Server - Avg_loss: 0.0383, Acc: 1020.0/1799 (0.5670)
# Server - Avg_loss: 0.0411, Acc: 974.0/1799 (0.5414)
# Server - Avg_loss: 0.0383, Acc: 1003.0/1807 (0.5551)
# Server - Avg_loss: 0.0424, Acc: 974.0/1805 (0.5396)
# Epoch: 62  mean: 0.5508	0.5377	0.5417	0.4832
#
# Client 0	Epoch:  0		Loss: 0.91079146
# Client 1	Epoch:  0		Loss: 1.19243598
# Client 2	Epoch:  0		Loss: 0.90490800
# Client 3	Epoch:  0		Loss: 0.99725896
# Server - Avg_loss: 0.0444, Acc: 912.0/1799 (0.5069)
# Server - Avg_loss: 0.0376, Acc: 1011.0/1807 (0.5595)
# Server - Avg_loss: 0.0426, Acc: 978.0/1805 (0.5418)
# Epoch: 63  mean: 0.5453	0.5211	0.5434	0.4768
#
# Client 0	Epoch:  0		Loss: 0.97447056
# Client 1	Epoch:  0		Loss: 0.94120109
# Client 2	Epoch:  0		Loss: 0.80641687
# Client 3	Epoch:  0		Loss: 0.42962465
# Server - Avg_loss: 0.0424, Acc: 974.0/1799 (0.5414)
# Server - Avg_loss: 0.0446, Acc: 952.0/1799 (0.5292)
# Server - Avg_loss: 0.0364, Acc: 1049.0/1807 (0.5805)
# Server - Avg_loss: 0.0489, Acc: 906.0/1805 (0.5019)
# Epoch: 64  mean: 0.5383	0.5063	0.5293	0.4622
#
# Client 0	Epoch:  0		Loss: 0.89222902
# Client 1	Epoch:  0		Loss: 0.93504643
# Client 2	Epoch:  0		Loss: 0.70336926
# Client 3	Epoch:  0		Loss: 0.74479580
# Server - Avg_loss: 0.0419, Acc: 972.0/1799 (0.5403)
# Server - Avg_loss: 0.0416, Acc: 973.0/1799 (0.5409)
# Server - Avg_loss: 0.0376, Acc: 1014.0/1807 (0.5612)
# Server - Avg_loss: 0.0434, Acc: 958.0/1805 (0.5307)
# Epoch: 65  mean: 0.5433	0.5171	0.5389	0.4705
#
# Client 0	Epoch:  0		Loss: 1.01860452
# Client 1	Epoch:  0		Loss: 1.12457407
# Client 2	Epoch:  0		Loss: 1.09065211
# Client 3	Epoch:  0		Loss: 1.12241638
# Server - Avg_loss: 0.0389, Acc: 1028.0/1799 (0.5714)
# Server - Avg_loss: 0.0456, Acc: 957.0/1799 (0.5320)
# Server - Avg_loss: 0.0342, Acc: 1079.0/1807 (0.5971)
# Server - Avg_loss: 0.0410, Acc: 1032.0/1805 (0.5717)
# Epoch: 66  mean: 0.5681	0.5396	0.5615	0.4990
#
# Client 0	Epoch:  0		Loss: 1.08043218
# Client 1	Epoch:  0		Loss: 0.99306530
# Client 2	Epoch:  0		Loss: 0.72701007
# Client 3	Epoch:  0		Loss: 1.09537959
# Server - Avg_loss: 0.0370, Acc: 1043.0/1799 (0.5798)
# Server - Avg_loss: 0.0423, Acc: 954.0/1799 (0.5303)
# Server - Avg_loss: 0.0364, Acc: 1061.0/1807 (0.5872)
# Server - Avg_loss: 0.0407, Acc: 1011.0/1805 (0.5601)
# Epoch: 67  mean: 0.5643	0.5366	0.5538	0.4942
#
# Client 0	Epoch:  0		Loss: 1.00975990
# Client 1	Epoch:  0		Loss: 0.84601122
# Client 2	Epoch:  0		Loss: 1.29111791
# Client 3	Epoch:  0		Loss: 0.73630190
# Server - Avg_loss: 0.0375, Acc: 1032.0/1799 (0.5737)
# Server - Avg_loss: 0.0395, Acc: 1035.0/1799 (0.5753)
# Server - Avg_loss: 0.0342, Acc: 1065.0/1807 (0.5894)
# Server - Avg_loss: 0.0392, Acc: 1048.0/1805 (0.5806)
# Epoch: 68  mean: 0.5797	0.5564	0.5710	0.5139
#
# Client 0	Epoch:  0		Loss: 0.95116711
# Client 1	Epoch:  0		Loss: 0.77108341
# Client 2	Epoch:  0		Loss: 1.10783362
# Client 3	Epoch:  0		Loss: 0.76835245
# Server - Avg_loss: 0.0395, Acc: 1041.0/1799 (0.5787)
# Server - Avg_loss: 0.0404, Acc: 972.0/1799 (0.5403)
# Server - Avg_loss: 0.0347, Acc: 1068.0/1807 (0.5910)
# Server - Avg_loss: 0.0378, Acc: 1073.0/1805 (0.5945)
# Epoch: 69  mean: 0.5761	0.5673	0.5687	0.5168
#
# Client 0	Epoch:  0		Loss: 1.09006131
# Client 1	Epoch:  0		Loss: 0.82984573
# Client 2	Epoch:  0		Loss: 1.01913416
# Client 3	Epoch:  0		Loss: 0.91207135
# Server - Avg_loss: 0.0386, Acc: 1032.0/1799 (0.5737)
# Server - Avg_loss: 0.0454, Acc: 912.0/1799 (0.5069)
# Server - Avg_loss: 0.0356, Acc: 1053.0/1807 (0.5827)
# Server - Avg_loss: 0.0371, Acc: 1046.0/1805 (0.5795)
# Epoch: 70  mean: 0.5607	0.5409	0.5591	0.4962
#
# Client 0	Epoch:  0		Loss: 1.14821124
# Client 1	Epoch:  0		Loss: 1.11381233
# Client 2	Epoch:  0		Loss: 0.76309907
# Client 3	Epoch:  0		Loss: 1.01590037
# Server - Avg_loss: 0.0402, Acc: 1010.0/1799 (0.5614)
# Server - Avg_loss: 0.0380, Acc: 1060.0/1799 (0.5892)
# Server - Avg_loss: 0.0321, Acc: 1133.0/1807 (0.6270)
# Server - Avg_loss: 0.0371, Acc: 1070.0/1805 (0.5928)
# Epoch: 71  mean: 0.5926	0.5564	0.5786	0.5222
#
# Client 0	Epoch:  0		Loss: 0.81855166
# Client 1	Epoch:  0		Loss: 1.07871342
# Client 2	Epoch:  0		Loss: 1.10706317
# Client 3	Epoch:  0		Loss: 1.08793926
# Server - Avg_loss: 0.0352, Acc: 1090.0/1799 (0.6059)
# Server - Avg_loss: 0.0397, Acc: 1017.0/1799 (0.5653)
# Server - Avg_loss: 0.0327, Acc: 1115.0/1807 (0.6170)
# Server - Avg_loss: 0.0416, Acc: 1003.0/1805 (0.5557)
# Epoch: 72  mean: 0.5860	0.5608	0.5774	0.5209
#
# Client 0	Epoch:  0		Loss: 0.76588631
# Client 1	Epoch:  0		Loss: 1.03339088
# Client 2	Epoch:  0		Loss: 0.82502425
# Client 3	Epoch:  0		Loss: 0.84588701
# Server - Avg_loss: 0.0354, Acc: 1084.0/1799 (0.6026)
# Server - Avg_loss: 0.0413, Acc: 1002.0/1799 (0.5570)
# Server - Avg_loss: 0.0337, Acc: 1084.0/1807 (0.5999)
# Server - Avg_loss: 0.0366, Acc: 1088.0/1805 (0.6028)
# Epoch: 73  mean: 0.5905	0.5688	0.5835	0.5276
#
# Client 0	Epoch:  0		Loss: 1.01034319
# Client 1	Epoch:  0		Loss: 0.83618557
# Client 2	Epoch:  0		Loss: 1.17112672
# Client 3	Epoch:  0		Loss: 1.26964867
# Server - Avg_loss: 0.0365, Acc: 1095.0/1799 (0.6087)
# Server - Avg_loss: 0.0398, Acc: 991.0/1799 (0.5509)
# Server - Avg_loss: 0.0354, Acc: 1057.0/1807 (0.5849)
# Server - Avg_loss: 0.0369, Acc: 1067.0/1805 (0.5911)
# Epoch: 74  mean: 0.5839	0.5726	0.5750	0.5205
#
# Client 0	Epoch:  0		Loss: 0.92050725
# Client 1	Epoch:  0		Loss: 0.89909369
# Client 2	Epoch:  0		Loss: 0.76962286
# Client 3	Epoch:  0		Loss: 0.94944364
# Server - Avg_loss: 0.0376, Acc: 1051.0/1799 (0.5842)
# Server - Avg_loss: 0.0419, Acc: 959.0/1799 (0.5331)
# Server - Avg_loss: 0.0376, Acc: 1038.0/1807 (0.5744)
# Server - Avg_loss: 0.0412, Acc: 1022.0/1805 (0.5662)
# Epoch: 75  mean: 0.5645	0.5418	0.5558	0.4951
#
# Client 0	Epoch:  0		Loss: 1.06538653
# Client 1	Epoch:  0		Loss: 1.12989628
# Client 2	Epoch:  0		Loss: 0.51493984
# Client 3	Epoch:  0		Loss: 1.12763071
# Server - Avg_loss: 0.0379, Acc: 1068.0/1799 (0.5937)
# Server - Avg_loss: 0.0410, Acc: 1012.0/1799 (0.5625)
# Server - Avg_loss: 0.0353, Acc: 1067.0/1807 (0.5905)
# Server - Avg_loss: 0.0429, Acc: 1001.0/1805 (0.5546)
# Epoch: 76  mean: 0.5753	0.5390	0.5636	0.4987
#
# Client 0	Epoch:  0		Loss: 0.92490256
# Client 1	Epoch:  0		Loss: 0.83513629
# Client 2	Epoch:  0		Loss: 1.04791868
# Client 3	Epoch:  0		Loss: 1.12590599
# Server - Avg_loss: 0.0358, Acc: 1084.0/1799 (0.6026)
# Server - Avg_loss: 0.0445, Acc: 962.0/1799 (0.5347)
# Server - Avg_loss: 0.0317, Acc: 1147.0/1807 (0.6348)
# Server - Avg_loss: 0.0364, Acc: 1093.0/1805 (0.6055)
# Epoch: 77  mean: 0.5944	0.5677	0.5849	0.5285
#
# Client 0	Epoch:  0		Loss: 0.57501358
# Client 1	Epoch:  0		Loss: 1.11007190
# Client 2	Epoch:  0		Loss: 0.80655330
# Client 3	Epoch:  0		Loss: 1.23040664
# Server - Avg_loss: 0.0395, Acc: 1029.0/1799 (0.5720)
# Server - Avg_loss: 0.0407, Acc: 1005.0/1799 (0.5586)
# Server - Avg_loss: 0.0371, Acc: 1054.0/1807 (0.5833)
# Server - Avg_loss: 0.0395, Acc: 1068.0/1805 (0.5917)
# Epoch: 78  mean: 0.5764	0.5538	0.5645	0.5052
#
# Client 0	Epoch:  0		Loss: 0.90919924
# Client 1	Epoch:  0		Loss: 0.79372257
# Client 2	Epoch:  0		Loss: 0.90214503
# Client 3	Epoch:  0		Loss: 0.93839884
# Server - Avg_loss: 0.0411, Acc: 1022.0/1799 (0.5681)
# Server - Avg_loss: 0.0390, Acc: 1015.0/1799 (0.5642)
# Server - Avg_loss: 0.0360, Acc: 1076.0/1807 (0.5955)
# Server - Avg_loss: 0.0410, Acc: 1019.0/1805 (0.5645)
# Epoch: 79  mean: 0.5731	0.5488	0.5601	0.5036
#
# Client 0	Epoch:  0		Loss: 1.19015110
# Client 1	Epoch:  0		Loss: 1.20100951
# Client 2	Epoch:  0		Loss: 0.93112296
# Client 3	Epoch:  0		Loss: 1.36826503
# Server - Avg_loss: 0.0355, Acc: 1098.0/1799 (0.6103)
# Server - Avg_loss: 0.0396, Acc: 1024.0/1799 (0.5692)
# Server - Avg_loss: 0.0345, Acc: 1076.0/1807 (0.5955)
# Server - Avg_loss: 0.0384, Acc: 1059.0/1805 (0.5867)
# Epoch: 80  mean: 0.5904	0.5608	0.5868	0.5261
#
# Client 0	Epoch:  0		Loss: 0.70829517
# Client 1	Epoch:  0		Loss: 1.14154530
# Client 2	Epoch:  0		Loss: 0.68203360
# Client 3	Epoch:  0		Loss: 0.96452069
# Server - Avg_loss: 0.0382, Acc: 1050.0/1799 (0.5837)
# Server - Avg_loss: 0.0391, Acc: 1045.0/1799 (0.5809)
# Server - Avg_loss: 0.0361, Acc: 1057.0/1807 (0.5849)
# Server - Avg_loss: 0.0392, Acc: 1047.0/1805 (0.5801)
# Epoch: 81  mean: 0.5824	0.5592	0.5781	0.5168
#
# Client 0	Epoch:  0		Loss: 0.78997624
# Client 1	Epoch:  0		Loss: 1.13268316
# Client 2	Epoch:  0		Loss: 0.85394925
# Client 3	Epoch:  0		Loss: 0.98002625
# Server - Avg_loss: 0.0374, Acc: 1073.0/1799 (0.5964)
# Server - Avg_loss: 0.0387, Acc: 1046.0/1799 (0.5814)
# Server - Avg_loss: 0.0337, Acc: 1105.0/1807 (0.6115)
# Server - Avg_loss: 0.0391, Acc: 1067.0/1805 (0.5911)
# Epoch: 82  mean: 0.5951	0.5698	0.5918	0.5304
#
# Client 0	Epoch:  0		Loss: 0.66756594
# Client 1	Epoch:  0		Loss: 1.09067798
# Client 2	Epoch:  0		Loss: 1.15091240
# Client 3	Epoch:  0		Loss: 0.88325357
# Server - Avg_loss: 0.0369, Acc: 1065.0/1799 (0.5920)
# Server - Avg_loss: 0.0395, Acc: 1013.0/1799 (0.5631)
# Server - Avg_loss: 0.0335, Acc: 1093.0/1807 (0.6049)
# Server - Avg_loss: 0.0403, Acc: 1033.0/1805 (0.5723)
# Epoch: 83  mean: 0.5831	0.5568	0.5779	0.5157
#
# Client 0	Epoch:  0		Loss: 0.88812870
# Client 1	Epoch:  0		Loss: 1.07554674
# Client 2	Epoch:  0		Loss: 0.82659143
# Client 3	Epoch:  0		Loss: 1.38426006
# Server - Avg_loss: 0.0339, Acc: 1122.0/1799 (0.6237)
# Server - Avg_loss: 0.0412, Acc: 1014.0/1799 (0.5636)
# Server - Avg_loss: 0.0333, Acc: 1119.0/1807 (0.6193)
# Server - Avg_loss: 0.0361, Acc: 1118.0/1805 (0.6194)
# Epoch: 84  mean: 0.6065	0.5737	0.5949	0.5391
#
# Client 0	Epoch:  0		Loss: 0.87380350
# Client 1	Epoch:  0		Loss: 0.86922687
# Client 2	Epoch:  0		Loss: 0.93243724
# Client 3	Epoch:  0		Loss: 0.91689974
# Server - Avg_loss: 0.0378, Acc: 1034.0/1799 (0.5748)
# Server - Avg_loss: 0.0413, Acc: 999.0/1799 (0.5553)
# Server - Avg_loss: 0.0354, Acc: 1071.0/1807 (0.5927)
# Server - Avg_loss: 0.0389, Acc: 1064.0/1805 (0.5895)
# Epoch: 85  mean: 0.5781	0.5650	0.5757	0.5162
#
# Client 0	Epoch:  0		Loss: 0.93935221
# Client 1	Epoch:  0		Loss: 1.01419330
# Client 2	Epoch:  0		Loss: 0.54320562
# Client 3	Epoch:  0		Loss: 0.68101335
# Server - Avg_loss: 0.0367, Acc: 1069.0/1799 (0.5942)
# Server - Avg_loss: 0.0372, Acc: 1057.0/1799 (0.5875)
# Server - Avg_loss: 0.0343, Acc: 1099.0/1807 (0.6082)
# Server - Avg_loss: 0.0377, Acc: 1090.0/1805 (0.6039)
# Epoch: 86  mean: 0.5985	0.5715	0.5942	0.5344
#
# Client 0	Epoch:  0		Loss: 1.11567032
# Client 1	Epoch:  0		Loss: 1.20903444
# Client 2	Epoch:  0		Loss: 0.65330976
# Client 3	Epoch:  0		Loss: 0.66376394
# Server - Avg_loss: 0.0379, Acc: 1061.0/1799 (0.5898)
# Server - Avg_loss: 0.0396, Acc: 1040.0/1799 (0.5781)
# Server - Avg_loss: 0.0316, Acc: 1151.0/1807 (0.6370)
# Server - Avg_loss: 0.0407, Acc: 1067.0/1805 (0.5911)
# Epoch: 87  mean: 0.5990	0.5589	0.5828	0.5264
#
# Client 0	Epoch:  0		Loss: 0.63146269
# Client 1	Epoch:  0		Loss: 0.66997814
# Client 2	Epoch:  0		Loss: 0.70700866
# Client 3	Epoch:  0		Loss: 1.09209824
# Server - Avg_loss: 0.0365, Acc: 1078.0/1799 (0.5992)
# Server - Avg_loss: 0.0388, Acc: 1039.0/1799 (0.5775)
# Server - Avg_loss: 0.0362, Acc: 1070.0/1807 (0.5921)
# Server - Avg_loss: 0.0398, Acc: 1069.0/1805 (0.5922)
# Epoch: 88  mean: 0.5903	0.5647	0.5801	0.5226
#
# Client 0	Epoch:  0		Loss: 0.87712193
# Client 1	Epoch:  0		Loss: 0.86577791
# Client 2	Epoch:  0		Loss: 0.81361836
# Client 3	Epoch:  0		Loss: 0.70418090
# Server - Avg_loss: 0.0381, Acc: 1071.0/1799 (0.5953)
# Server - Avg_loss: 0.0387, Acc: 1062.0/1799 (0.5903)
# Server - Avg_loss: 0.0348, Acc: 1079.0/1807 (0.5971)
# Server - Avg_loss: 0.0381, Acc: 1087.0/1805 (0.6022)
# Epoch: 89  mean: 0.5962	0.5678	0.5876	0.5279
#
# Client 0	Epoch:  0		Loss: 1.08389664
# Client 1	Epoch:  0		Loss: 1.07776189
# Client 2	Epoch:  0		Loss: 0.96955830
# Client 3	Epoch:  0		Loss: 0.94675303
# Server - Avg_loss: 0.0396, Acc: 1026.0/1799 (0.5703)
# Server - Avg_loss: 0.0438, Acc: 1003.0/1799 (0.5575)
# Server - Avg_loss: 0.0342, Acc: 1105.0/1807 (0.6115)
# Server - Avg_loss: 0.0382, Acc: 1077.0/1805 (0.5967)
# Epoch: 90  mean: 0.5840	0.5580	0.5794	0.5171
#
# Client 0	Epoch:  0		Loss: 0.46137589
# Client 1	Epoch:  0		Loss: 1.48792851
# Client 2	Epoch:  0		Loss: 1.01677537
# Client 3	Epoch:  0		Loss: 0.78120583
# Server - Avg_loss: 0.0390, Acc: 1074.0/1799 (0.5970)
# Server - Avg_loss: 0.0419, Acc: 1020.0/1799 (0.5670)
# Server - Avg_loss: 0.0351, Acc: 1092.0/1807 (0.6043)
# Server - Avg_loss: 0.0397, Acc: 1070.0/1805 (0.5928)
# Epoch: 91  mean: 0.5903	0.5598	0.5785	0.5197
#
# Client 0	Epoch:  0		Loss: 0.87564117
# Client 1	Epoch:  0		Loss: 1.15614164
# Client 2	Epoch:  0		Loss: 0.45125362
# Client 3	Epoch:  0		Loss: 1.10460973
# Server - Avg_loss: 0.0374, Acc: 1083.0/1799 (0.6020)
# Server - Avg_loss: 0.0379, Acc: 1080.0/1799 (0.6003)
# Server - Avg_loss: 0.0350, Acc: 1113.0/1807 (0.6159)
# Server - Avg_loss: 0.0394, Acc: 1078.0/1805 (0.5972)
# Epoch: 92  mean: 0.6039	0.5820	0.5959	0.5423
#
# Client 0	Epoch:  0		Loss: 1.11057889
# Client 1	Epoch:  0		Loss: 1.00023127

# %%
# unlearn one client
unlearn_id = 3
write_log(log_path, '\n unlearn_id: {}'.format(unlearn_id))
del device_dict[unlearn_id]
print(device_dict.keys())

# %%
# reinitialize

start_time = time.time()
for i in range(10):
    device_dict[0].train_local_model(num_iter=3, local_loader=loader_dict[device_id][0])
    device_dict[0].communication(frac=1, gamma=0.9, device_dict=device_dict)
iter_time = (time.time() - start_time)/10

if Heterogeneous == 1:
    # heterogeneous scenario
    write_log(log_path, 'heterogeneous')
    for device_id in device_dict.keys():
        gpu_id = 0
        device_dict[device_id].model = ResNet8(num_channel) if ModelType == 'resnet' else MobileNet_S(num_channel)
        device_dict[device_id].model.cuda(gpu_id)
        device_dict[device_id].optimizer = optim.Adam(device_dict[device_id].model.parameters(), lr=0.01)
else:
    # homogeneous scenario
    write_log(log_path, 'homogeneous')
    for device_id in device_dict.keys():
        gpu_id = 0
        device_dict[device_id].model = ResNet50(num_channel) if ModelType == 'resnet' else MobileNet_L(num_channel)
        device_dict[device_id].model.cuda(gpu_id)
        device_dict[device_id].optimizer = optim.Adam(device_dict[device_id].model.parameters(), lr=0.01)
        
metric = []
for device_id, device in device_dict.items():
    metric.append(device.validate_local_model(test_loader=loader_dict[device_id][1]))
metric_arr=np.array(metric)
log_txt = '{:.4f}\t{:.4f}\t{:.4f}\t{:.4f}'.format(np.mean(metric_arr, axis=0)[0], 
                                  np.mean(metric_arr, axis=0)[1],np.mean(metric_arr, axis=0)[2],
                                  np.mean(metric_arr, axis=0)[3])
print('mean: '+ log_txt)
write_log(log_path, log_txt)

# %%
# retrain models
epoch_num = 150 if ModelType == 'resnet' else 100
write_log(log_path, time.ctime(time.time()))
iter_num = int(60/iter_time/len(device_dict))
start_time = time.time()
for epoch in range(epoch_num):
    for i in range(iter_num):
        for device_id, device in device_dict.items():
            device.train_local_model(num_iter=3, local_loader=loader_dict[device_id][0])
            device.communication(frac=1, gamma=0.9, device_dict=device_dict)
        print('remedy time consumption(s): {}'.format(time.time() - start_time))
    if time.time() - start_time < 60*(epoch+1):
        iter_num+=1
    else:
        iter_num-=1
            
    metric = []
    for device_id, device in device_dict.items():
        metric.append(device.validate_local_model(test_loader=loader_dict[device_id][1]))
    metric_arr=np.array(metric)
    log_txt = '{:.4f}\t{:.4f}\t{:.4f}\t{:.4f}'.format(np.mean(metric_arr, axis=0)[0], 
                                      np.mean(metric_arr, axis=0)[1],np.mean(metric_arr, axis=0)[2],
                                      np.mean(metric_arr, axis=0)[3])
    print('Epoch: {}  mean: {}'.format(epoch, log_txt), end='\n\n')
    write_log(log_path, log_txt)

# %%
# train the client for rejoin
device_back_up.train_local_model(num_iter=200, local_loader=loader_dict[4][0])

# %%
device_dict[unlearn_id] = device_back_up
loader_dict[unlearn_id] = loader_dict[4]
# assign neighbors
for k, v in device_dict.items():
    # full neighbor list
    neighbor_list = [x for x in device_dict.keys() if x != k]  
    v.neighbor_list = neighbor_list

metric = []
for device_id, device in device_dict.items():
    metric.append(device.validate_local_model(test_loader=loader_dict[device_id][1]))
metric_arr=np.array(metric)
log_txt = '{:.4f}\t{:.4f}\t{:.4f}\t{:.4f}'.format(np.mean(metric_arr, axis=0)[0], 
                                  np.mean(metric_arr, axis=0)[1],np.mean(metric_arr, axis=0)[2],
                                  np.mean(metric_arr, axis=0)[3])
print('Epoch: {}  mean: {}'.format(0, log_txt), end='\n\n')
write_log(log_path, log_txt)

# %%
# performance recovery
metric = []
epoch_num = 100 if ModelType == 'resnet' else 100
write_log(log_path, 'Recovering')
write_log(log_path, time.ctime(time.time()))
iter_num = int(10/iter_time/len(device_dict))
start_time = time.time()
for epoch in range(epoch_num):
    for i in range(iter_num):
        for device_id, device in device_dict.items():
            device.train_local_model(num_iter=3, local_loader=loader_dict[device_id][0])
            device.communication(frac=1, gamma=0.9, device_dict=device_dict)
        print('remedy time consumption(s): {}'.format(time.time() - start_time))
    if time.time() - start_time < 10*(epoch+1):
        iter_num+=1
    else:
        iter_num-=1
            
    metric = []
    for device_id, device in device_dict.items():
        metric.append(device.validate_local_model(test_loader=loader_dict[device_id][1]))
    metric_arr=np.array(metric)
    log_txt = '{:.4f}\t{:.4f}\t{:.4f}\t{:.4f}'.format(np.mean(metric_arr, axis=0)[0], 
                                      np.mean(metric_arr, axis=0)[1],np.mean(metric_arr, axis=0)[2],
                                      np.mean(metric_arr, axis=0)[3])
    print('Epoch: {}  mean: {}'.format(epoch, log_txt), end='\n\n')
    write_log(log_path, log_txt)
