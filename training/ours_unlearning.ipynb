# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Subset, DataLoader
from torchvision import datasets, transforms
import random
import time
import sys

sys.path.append("..")
from utils.tool import GPU_info, write_log, print_label_stat
from models.resnet import ResNet8, ResNet18, ResNet50
from models.mobilenet import MobileNet_S, MobileNet_M, MobileNet_L
from framework.ours import Device
from framework.DSGD import DSGD_Device
from framework.SISA import SISA_Device
from framework.FedAvgUnl import FedAvgServer, FedAvgClient


# one in ['ours', 'DSGD', 'SISA', 'Fed']
Framework = 'ours'

# one in ['MNIST', 'FMNIST', 'CIFAR10']
DatasetName = 'MNIST'

# one in ['resnet', 'mobilenet']
ModelType = 'mobilenet'

# one in [1,0]. 1 - Heterogeneous;  0 - Homogeneous
Heterogeneous = 1

# %%
train_set_o = None
test_set_o = None
num_classes = 10
device_num = 5
num_channel = 1
ref_size = 10000
train_test_total_size = int(50000/device_num)
test_ratio = 0.2

train_batch_size = 256 if ModelType == 'resnet' else 32
save_path = './checkpoint'
data_path = '../data'
log_path = '../log/unlearn_{}_{}_{}.txt'.format(Framework, ModelType, DatasetName)

my_seed = 1
torch.cuda.manual_seed(my_seed)

if DatasetName == 'CIFAR10':
    train_set_o = datasets.CIFAR10(data_path, train=True, download=True)
    test_set_o = datasets.CIFAR10(data_path, train=False, download=True)
    num_channel = 3

elif DatasetName == 'MNIST':    
    train_set_o = datasets.MNIST(data_path, train=True, download=True)
    test_set_o = datasets.MNIST(data_path, train=False, download=True)

elif DatasetName == 'FMNIST':    
    train_set_o = datasets.FashionMNIST(data_path, train=True, download=True)
    test_set_o = datasets.FashionMNIST(data_path, train=False, download=True)

train_set_o.transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,)),
])

test_set_o.transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,)),
])

ref_set = Subset(test_set_o, range(0,int(ref_size)))
ref_loader = torch.utils.data.DataLoader(ref_set, batch_size=train_batch_size,
                                         shuffle=False, num_workers=0)

# %%
# data manipulation
device_dict = {}
loader_dict = {}
print('Device', end='\t')
for class_id in range(num_classes):
    print('Class'+str(class_id), end='\t')
print('SUM')
for device_id in range(device_num):
    range_start = train_test_total_size * device_id
    range_end = range_start + train_test_total_size
    # remove one class from each local dataset
    class_to_remove = torch.tensor(device_id%10)
    indices = (torch.tensor(train_set_o.targets[range_start:range_end])[..., None] !=
               class_to_remove).any(-1).nonzero(as_tuple=True)[0]
    # split train&test
    train_test_border = int((1-test_ratio)*len(indices))
    train_set = Subset(train_set_o, indices[:train_test_border]+range_start)
    test_set = Subset(train_set_o, indices[train_test_border:]+range_start)
    train_loader = DataLoader(train_set, batch_size=train_batch_size,
                              shuffle=True, num_workers=0)
    test_loader = DataLoader(test_set, batch_size=train_batch_size,
                             shuffle=True, num_workers=0) 
    loader_dict[device_id] = [train_loader, test_loader]
    print_label_stat(device_id, train_set, num_classes)

# initialize devices
for device_id in range(device_num):
    gpu_id = 0
    device_dict[device_id] = Device(device_id, gpu_id, num_classes, num_channel)
# Out:
# Device	Class0	Class1	Class2	Class3	Class4	Class5	Class6	Class7	Class8	Class9	SUM
# D-0	0	905	788	811	798	701	797	852	752	795	7199
# D-1	782	0	749	851	767	724	757	830	788	828	7076
# D-2	757	919	0	819	781	751	803	813	759	782	7184
# D-3	758	905	798	0	783	710	794	819	798	828	7193
# D-4	804	901	817	807	0	719	773	842	792	785	7240

# %%
# assign neighbors
for k, v in device_dict.items():
    # full neighbor list SMLLL'
    neighbor_list = [x for x in device_dict.keys() if x != k]
    v.neighbor_list = neighbor_list
    
for k, v in device_dict.items():
    print('D_{}: {}'.format(k, v.neighbor_list))
# Out:
# D_0: [1, 2, 3, 4]
# D_1: [0, 2, 3, 4]
# D_2: [0, 1, 3, 4]
# D_3: [0, 1, 2, 4]
# D_4: [0, 1, 2, 3]

# %%
# heterogenerous scenario 
write_log(log_path, DatasetName+' heterogenerous')
if Heterogeneous == 1:
    # heterogeneous scenario
    write_log(log_path, 'heterogeneous')
    for device_id in range(device_num):
        gpu_id = 0
        if device_id < 1:
            device_dict[device_id].main_model = ResNet8(num_channel) if ModelType == 'resnet' else MobileNet_S(num_channel)
        elif device_id < 2:
            device_dict[device_id].main_model = ResNet18(num_channel) if ModelType == 'resnet' else MobileNet_M(num_channel)
        else:
            device_dict[device_id].main_model = ResNet50(num_channel) if ModelType == 'resnet' else MobileNet_L(num_channel)
        device_dict[device_id].main_model.cuda(gpu_id)

else:
    # homogeneous scenario
    write_log(log_path, 'homogeneous')
    for device_id in range(device_num):
        gpu_id = 0
        device_dict[device_id].main_model = ResNet50(num_channel) if ModelType == 'resnet' else MobileNet_L(num_channel)
        device_dict[device_id].main_model.cuda(gpu_id)

# %%
# train local main models
num_iter = 1000 if ModelType == 'resnet' else 501
metric = []
for k, v in device_dict.items():
#     v.train_main_model(num_iter, loader_dict[k][0])
    metric.append(v.validate_main_model(loader_dict[k][1]))
    v.update_soft_label(ref_loader)
    GPU_info([v.gpu_id])
metric_arr = np.array(metric)
log_txt = 'Avg_acc: {:.4f}'.format(np.mean(metric_arr, axis=0)[0])
print(log_txt)
# Out:
# Device: 0 Val_main - Avg_loss: 0.1614, Acc: 1745.0/1800 (0.9694)
# GPU0-0.0563G
# Device: 1 Val_main - Avg_loss: 0.0725, Acc: 1749.0/1770 (0.9881)
# GPU0-0.0563G
# Device: 2 Val_main - Avg_loss: 0.0502, Acc: 1778.0/1797 (0.9894)
# GPU0-0.0563G
# Device: 3 Val_main - Avg_loss: 0.0562, Acc: 1779.0/1799 (0.9889)
# GPU0-0.0563G
# Device: 4 Val_main - Avg_loss: 0.0515, Acc: 1790.0/1810 (0.9890)
# GPU0-0.0563G
# Avg_acc: 0.9850

# %%
# train seed models
T_ = 9
num_iter = 800 if ModelType == 'resnet' else 3001
for k, v in device_dict.items():
    v.seed_model = ResNet8(num_channel) if ModelType == 'resnet' else MobileNet_S(num_channel)
    v.seed_model.cuda(gpu_id) 
    v.train_seed_model(ref_set, num_iter=num_iter, batch_size=int(ref_size*0.2), T=T_)
    print('\n')
# Out:
# Device:0 Trn_Seed - Epoch:   0 	Loss: 0.900630
# Device:0 Trn_Seed - Epoch:  50 	Loss: 0.730935
# Device:0 Trn_Seed - Epoch: 100 	Loss: 0.545694
# Device:0 Trn_Seed - Epoch: 150 	Loss: 0.388388
# Device:0 Trn_Seed - Epoch: 200 	Loss: 0.285739
# Device:0 Trn_Seed - Epoch: 250 	Loss: 0.219916
# Device:0 Trn_Seed - Epoch: 300 	Loss: 0.173411
# Device:0 Trn_Seed - Epoch: 350 	Loss: 0.144517
# Device:0 Trn_Seed - Epoch: 400 	Loss: 0.122088
# Device:0 Trn_Seed - Epoch: 450 	Loss: 0.109289
# Device:0 Trn_Seed - Epoch: 500 	Loss: 0.092158
# Device:0 Trn_Seed - Epoch: 550 	Loss: 0.081440
# Device:0 Trn_Seed - Epoch: 600 	Loss: 0.073397
# Device:0 Trn_Seed - Epoch: 650 	Loss: 0.065570
# Device:0 Trn_Seed - Epoch: 700 	Loss: 0.059073
# Device:0 Trn_Seed - Epoch: 750 	Loss: 0.056906
# Device:0 Trn_Seed - Epoch: 800 	Loss: 0.053968
# Device:0 Trn_Seed - Epoch: 850 	Loss: 0.051793
# Device:0 Trn_Seed - Epoch: 900 	Loss: 0.052474
# Device:0 Trn_Seed - Epoch: 950 	Loss: 0.049455
# Device:0 Trn_Seed - Epoch: 1000 	Loss: 0.045658
# Device:0 Trn_Seed - Epoch: 1050 	Loss: 0.047006
# Device:0 Trn_Seed - Epoch: 1100 	Loss: 0.045822
# Device:0 Trn_Seed - Epoch: 1150 	Loss: 0.042377
# Device:0 Trn_Seed - Epoch: 1200 	Loss: 0.042048
# Device:0 Trn_Seed - Epoch: 1250 	Loss: 0.044614
# Device:0 Trn_Seed - Epoch: 1300 	Loss: 0.042672
# Device:0 Trn_Seed - Epoch: 1350 	Loss: 0.042948
# Device:0 Trn_Seed - Epoch: 1400 	Loss: 0.040969
# Device:0 Trn_Seed - Epoch: 1450 	Loss: 0.039148
# Device:0 Trn_Seed - Epoch: 1500 	Loss: 0.038150
# Device:0 Trn_Seed - Epoch: 1550 	Loss: 0.038155
# Device:0 Trn_Seed - Epoch: 1600 	Loss: 0.038282
# Device:0 Trn_Seed - Epoch: 1650 	Loss: 0.037766
# Device:0 Trn_Seed - Epoch: 1700 	Loss: 0.035426
# Device:0 Trn_Seed - Epoch: 1750 	Loss: 0.035778
# Device:0 Trn_Seed - Epoch: 1800 	Loss: 0.035023
# Device:0 Trn_Seed - Epoch: 1850 	Loss: 0.036709
# Device:0 Trn_Seed - Epoch: 1900 	Loss: 0.033621
# Device:0 Trn_Seed - Epoch: 1950 	Loss: 0.033658
# Device:0 Trn_Seed - Epoch: 2000 	Loss: 0.033694
# Device:0 Trn_Seed - Epoch: 2050 	Loss: 0.033497
# Device:0 Trn_Seed - Epoch: 2100 	Loss: 0.032500
# Device:0 Trn_Seed - Epoch: 2150 	Loss: 0.032910
# Device:0 Trn_Seed - Epoch: 2200 	Loss: 0.033782
# Device:0 Trn_Seed - Epoch: 2250 	Loss: 0.031071
# Device:0 Trn_Seed - Epoch: 2300 	Loss: 0.032127
# Device:0 Trn_Seed - Epoch: 2350 	Loss: 0.032482
# Device:0 Trn_Seed - Epoch: 2400 	Loss: 0.030225
# Device:0 Trn_Seed - Epoch: 2450 	Loss: 0.032048
# Device:0 Trn_Seed - Epoch: 2500 	Loss: 0.030619
# Device:0 Trn_Seed - Epoch: 2550 	Loss: 0.031225
# Device:0 Trn_Seed - Epoch: 2600 	Loss: 0.031733
# Device:0 Trn_Seed - Epoch: 2650 	Loss: 0.030644
# Device:0 Trn_Seed - Epoch: 2700 	Loss: 0.030075
# Device:0 Trn_Seed - Epoch: 2750 	Loss: 0.032284
# Device:0 Trn_Seed - Epoch: 2800 	Loss: 0.030851
# Device:0 Trn_Seed - Epoch: 2850 	Loss: 0.030528
# Device:0 Trn_Seed - Epoch: 2900 	Loss: 0.029418
# Device:0 Trn_Seed - Epoch: 2950 	Loss: 0.030223
# Device:0 Trn_Seed - Epoch: 3000 	Loss: 0.030367
#
#
# Device:1 Trn_Seed - Epoch:   0 	Loss: 1.267759
# Device:1 Trn_Seed - Epoch:  50 	Loss: 1.105051
# Device:1 Trn_Seed - Epoch: 100 	Loss: 0.941120
# Device:1 Trn_Seed - Epoch: 150 	Loss: 0.782436
# Device:1 Trn_Seed - Epoch: 200 	Loss: 0.662191
# Device:1 Trn_Seed - Epoch: 250 	Loss: 0.536797
# Device:1 Trn_Seed - Epoch: 300 	Loss: 0.430163
# Device:1 Trn_Seed - Epoch: 350 	Loss: 0.343043
# Device:1 Trn_Seed - Epoch: 400 	Loss: 0.286540
# Device:1 Trn_Seed - Epoch: 450 	Loss: 0.244070
# Device:1 Trn_Seed - Epoch: 500 	Loss: 0.209008
# Device:1 Trn_Seed - Epoch: 550 	Loss: 0.174335
# Device:1 Trn_Seed - Epoch: 600 	Loss: 0.154295
# Device:1 Trn_Seed - Epoch: 650 	Loss: 0.140472
# Device:1 Trn_Seed - Epoch: 700 	Loss: 0.127136
# Device:1 Trn_Seed - Epoch: 750 	Loss: 0.126028
# Device:1 Trn_Seed - Epoch: 800 	Loss: 0.113724
# Device:1 Trn_Seed - Epoch: 850 	Loss: 0.107227
# Device:1 Trn_Seed - Epoch: 900 	Loss: 0.104206
# Device:1 Trn_Seed - Epoch: 950 	Loss: 0.098283
# Device:1 Trn_Seed - Epoch: 1000 	Loss: 0.089932
# Device:1 Trn_Seed - Epoch: 1050 	Loss: 0.089193
# Device:1 Trn_Seed - Epoch: 1100 	Loss: 0.088395
# Device:1 Trn_Seed - Epoch: 1150 	Loss: 0.085425
# Device:1 Trn_Seed - Epoch: 1200 	Loss: 0.080679
# Device:1 Trn_Seed - Epoch: 1250 	Loss: 0.079051
# Device:1 Trn_Seed - Epoch: 1300 	Loss: 0.081848
# Device:1 Trn_Seed - Epoch: 1350 	Loss: 0.070554
# Device:1 Trn_Seed - Epoch: 1400 	Loss: 0.070058
# Device:1 Trn_Seed - Epoch: 1450 	Loss: 0.071351
# Device:1 Trn_Seed - Epoch: 1500 	Loss: 0.071460
# Device:1 Trn_Seed - Epoch: 1550 	Loss: 0.067525
# Device:1 Trn_Seed - Epoch: 1600 	Loss: 0.067037
# Device:1 Trn_Seed - Epoch: 1650 	Loss: 0.065633
# Device:1 Trn_Seed - Epoch: 1700 	Loss: 0.063639
# Device:1 Trn_Seed - Epoch: 1750 	Loss: 0.065516
# Device:1 Trn_Seed - Epoch: 1800 	Loss: 0.063662
# Device:1 Trn_Seed - Epoch: 1850 	Loss: 0.063304
# Device:1 Trn_Seed - Epoch: 1900 	Loss: 0.062267
# Device:1 Trn_Seed - Epoch: 1950 	Loss: 0.060900
# Device:1 Trn_Seed - Epoch: 2000 	Loss: 0.061732
# Device:1 Trn_Seed - Epoch: 2050 	Loss: 0.059919
# Device:1 Trn_Seed - Epoch: 2100 	Loss: 0.061545
# Device:1 Trn_Seed - Epoch: 2150 	Loss: 0.061258
# Device:1 Trn_Seed - Epoch: 2200 	Loss: 0.056485
# Device:1 Trn_Seed - Epoch: 2250 	Loss: 0.059878
# Device:1 Trn_Seed - Epoch: 2300 	Loss: 0.055776
# Device:1 Trn_Seed - Epoch: 2350 	Loss: 0.057194
# Device:1 Trn_Seed - Epoch: 2400 	Loss: 0.057166
# Device:1 Trn_Seed - Epoch: 2450 	Loss: 0.054441
# Device:1 Trn_Seed - Epoch: 2500 	Loss: 0.053477
# Device:1 Trn_Seed - Epoch: 2550 	Loss: 0.053605
# Device:1 Trn_Seed - Epoch: 2600 	Loss: 0.056734
# Device:1 Trn_Seed - Epoch: 2650 	Loss: 0.053898
# Device:1 Trn_Seed - Epoch: 2700 	Loss: 0.052894
# Device:1 Trn_Seed - Epoch: 2750 	Loss: 0.052841
# Device:1 Trn_Seed - Epoch: 2800 	Loss: 0.055341
# Device:1 Trn_Seed - Epoch: 2850 	Loss: 0.051617
# Device:1 Trn_Seed - Epoch: 2900 	Loss: 0.051661
# Device:1 Trn_Seed - Epoch: 2950 	Loss: 0.051019
# Device:1 Trn_Seed - Epoch: 3000 	Loss: 0.054700
#
#
# Device:2 Trn_Seed - Epoch:   0 	Loss: 1.120232
# Device:2 Trn_Seed - Epoch:  50 	Loss: 0.939173
# Device:2 Trn_Seed - Epoch: 100 	Loss: 0.685984
# Device:2 Trn_Seed - Epoch: 150 	Loss: 0.539888
# Device:2 Trn_Seed - Epoch: 200 	Loss: 0.451815
# Device:2 Trn_Seed - Epoch: 250 	Loss: 0.378247
# Device:2 Trn_Seed - Epoch: 300 	Loss: 0.297347
# Device:2 Trn_Seed - Epoch: 350 	Loss: 0.233815
# Device:2 Trn_Seed - Epoch: 400 	Loss: 0.191240
# Device:2 Trn_Seed - Epoch: 450 	Loss: 0.153433
# Device:2 Trn_Seed - Epoch: 500 	Loss: 0.134522
# Device:2 Trn_Seed - Epoch: 550 	Loss: 0.121605
# Device:2 Trn_Seed - Epoch: 600 	Loss: 0.114504
# Device:2 Trn_Seed - Epoch: 650 	Loss: 0.107923
# Device:2 Trn_Seed - Epoch: 700 	Loss: 0.100226
# Device:2 Trn_Seed - Epoch: 750 	Loss: 0.093620
# Device:2 Trn_Seed - Epoch: 800 	Loss: 0.091370
# Device:2 Trn_Seed - Epoch: 850 	Loss: 0.088879
# Device:2 Trn_Seed - Epoch: 900 	Loss: 0.085832
# Device:2 Trn_Seed - Epoch: 950 	Loss: 0.081752
# Device:2 Trn_Seed - Epoch: 1000 	Loss: 0.080909
# Device:2 Trn_Seed - Epoch: 1050 	Loss: 0.076619
# Device:2 Trn_Seed - Epoch: 1100 	Loss: 0.075767
# Device:2 Trn_Seed - Epoch: 1150 	Loss: 0.074091
# Device:2 Trn_Seed - Epoch: 1200 	Loss: 0.072452
# Device:2 Trn_Seed - Epoch: 1250 	Loss: 0.072186
# Device:2 Trn_Seed - Epoch: 1300 	Loss: 0.073569
# Device:2 Trn_Seed - Epoch: 1350 	Loss: 0.073615
# Device:2 Trn_Seed - Epoch: 1400 	Loss: 0.070716
# Device:2 Trn_Seed - Epoch: 1450 	Loss: 0.068852
# Device:2 Trn_Seed - Epoch: 1500 	Loss: 0.067592
# Device:2 Trn_Seed - Epoch: 1550 	Loss: 0.066072
# Device:2 Trn_Seed - Epoch: 1600 	Loss: 0.066211
# Device:2 Trn_Seed - Epoch: 1650 	Loss: 0.066366
# Device:2 Trn_Seed - Epoch: 1700 	Loss: 0.063570
# Device:2 Trn_Seed - Epoch: 1750 	Loss: 0.062203
# Device:2 Trn_Seed - Epoch: 1800 	Loss: 0.061254
# Device:2 Trn_Seed - Epoch: 1850 	Loss: 0.064250
# Device:2 Trn_Seed - Epoch: 1900 	Loss: 0.063774
# Device:2 Trn_Seed - Epoch: 1950 	Loss: 0.063910
# Device:2 Trn_Seed - Epoch: 2000 	Loss: 0.062038
# Device:2 Trn_Seed - Epoch: 2050 	Loss: 0.061832
# Device:2 Trn_Seed - Epoch: 2100 	Loss: 0.061894
# Device:2 Trn_Seed - Epoch: 2150 	Loss: 0.061578
# Device:2 Trn_Seed - Epoch: 2200 	Loss: 0.060164
# Device:2 Trn_Seed - Epoch: 2250 	Loss: 0.060479
# Device:2 Trn_Seed - Epoch: 2300 	Loss: 0.059797
# Device:2 Trn_Seed - Epoch: 2350 	Loss: 0.058143
# Device:2 Trn_Seed - Epoch: 2400 	Loss: 0.058247
# Device:2 Trn_Seed - Epoch: 2450 	Loss: 0.057780
# Device:2 Trn_Seed - Epoch: 2500 	Loss: 0.057213
# Device:2 Trn_Seed - Epoch: 2550 	Loss: 0.058556
# Device:2 Trn_Seed - Epoch: 2600 	Loss: 0.058231
# Device:2 Trn_Seed - Epoch: 2650 	Loss: 0.058025
# Device:2 Trn_Seed - Epoch: 2700 	Loss: 0.056436
# Device:2 Trn_Seed - Epoch: 2750 	Loss: 0.059217
# Device:2 Trn_Seed - Epoch: 2800 	Loss: 0.055289
# Device:2 Trn_Seed - Epoch: 2850 	Loss: 0.055426
# Device:2 Trn_Seed - Epoch: 2900 	Loss: 0.054843
# Device:2 Trn_Seed - Epoch: 2950 	Loss: 0.055026
# Device:2 Trn_Seed - Epoch: 3000 	Loss: 0.054920
#
#
# Device:3 Trn_Seed - Epoch:   0 	Loss: 1.068792
# Device:3 Trn_Seed - Epoch:  50 	Loss: 0.888920
# Device:3 Trn_Seed - Epoch: 100 	Loss: 0.696302
# Device:3 Trn_Seed - Epoch: 150 	Loss: 0.551328
# Device:3 Trn_Seed - Epoch: 200 	Loss: 0.464246
# Device:3 Trn_Seed - Epoch: 250 	Loss: 0.383986
# Device:3 Trn_Seed - Epoch: 300 	Loss: 0.304591
# Device:3 Trn_Seed - Epoch: 350 	Loss: 0.251972
# Device:3 Trn_Seed - Epoch: 400 	Loss: 0.222261
# Device:3 Trn_Seed - Epoch: 450 	Loss: 0.189559
# Device:3 Trn_Seed - Epoch: 500 	Loss: 0.161872
# Device:3 Trn_Seed - Epoch: 550 	Loss: 0.148727
# Device:3 Trn_Seed - Epoch: 600 	Loss: 0.143104
# Device:3 Trn_Seed - Epoch: 650 	Loss: 0.126747
# Device:3 Trn_Seed - Epoch: 700 	Loss: 0.118079
# Device:3 Trn_Seed - Epoch: 750 	Loss: 0.109623
# Device:3 Trn_Seed - Epoch: 800 	Loss: 0.107334
# Device:3 Trn_Seed - Epoch: 850 	Loss: 0.098169
# Device:3 Trn_Seed - Epoch: 900 	Loss: 0.103697
# Device:3 Trn_Seed - Epoch: 950 	Loss: 0.095215
# Device:3 Trn_Seed - Epoch: 1000 	Loss: 0.096502
# Device:3 Trn_Seed - Epoch: 1050 	Loss: 0.092402
# Device:3 Trn_Seed - Epoch: 1100 	Loss: 0.094735
# Device:3 Trn_Seed - Epoch: 1150 	Loss: 0.087828
# Device:3 Trn_Seed - Epoch: 1200 	Loss: 0.084640
# Device:3 Trn_Seed - Epoch: 1250 	Loss: 0.088682
# Device:3 Trn_Seed - Epoch: 1300 	Loss: 0.084054
# Device:3 Trn_Seed - Epoch: 1350 	Loss: 0.079466
# Device:3 Trn_Seed - Epoch: 1400 	Loss: 0.074908
# Device:3 Trn_Seed - Epoch: 1450 	Loss: 0.074518
# Device:3 Trn_Seed - Epoch: 1500 	Loss: 0.070419
# Device:3 Trn_Seed - Epoch: 1550 	Loss: 0.068101
# Device:3 Trn_Seed - Epoch: 1600 	Loss: 0.070145
# Device:3 Trn_Seed - Epoch: 1650 	Loss: 0.063298
# Device:3 Trn_Seed - Epoch: 1700 	Loss: 0.064081
# Device:3 Trn_Seed - Epoch: 1750 	Loss: 0.060808
# Device:3 Trn_Seed - Epoch: 1800 	Loss: 0.061340
# Device:3 Trn_Seed - Epoch: 1850 	Loss: 0.058918
# Device:3 Trn_Seed - Epoch: 1900 	Loss: 0.059006
# Device:3 Trn_Seed - Epoch: 1950 	Loss: 0.055420
# Device:3 Trn_Seed - Epoch: 2000 	Loss: 0.052930
# Device:3 Trn_Seed - Epoch: 2050 	Loss: 0.055016
# Device:3 Trn_Seed - Epoch: 2100 	Loss: 0.052535
# Device:3 Trn_Seed - Epoch: 2150 	Loss: 0.053942
# Device:3 Trn_Seed - Epoch: 2200 	Loss: 0.066592
# Device:3 Trn_Seed - Epoch: 2250 	Loss: 0.052609
# Device:3 Trn_Seed - Epoch: 2300 	Loss: 0.053496
# Device:3 Trn_Seed - Epoch: 2350 	Loss: 0.048658
# Device:3 Trn_Seed - Epoch: 2400 	Loss: 0.048171
# Device:3 Trn_Seed - Epoch: 2450 	Loss: 0.050957
# Device:3 Trn_Seed - Epoch: 2500 	Loss: 0.048744
# Device:3 Trn_Seed - Epoch: 2550 	Loss: 0.046723
# Device:3 Trn_Seed - Epoch: 2600 	Loss: 0.044978
# Device:3 Trn_Seed - Epoch: 2650 	Loss: 0.046984
# Device:3 Trn_Seed - Epoch: 2700 	Loss: 0.047037
# Device:3 Trn_Seed - Epoch: 2750 	Loss: 0.048063
# Device:3 Trn_Seed - Epoch: 2800 	Loss: 0.048851
# Device:3 Trn_Seed - Epoch: 2850 	Loss: 0.048077
# Device:3 Trn_Seed - Epoch: 2900 	Loss: 0.046058
# Device:3 Trn_Seed - Epoch: 2950 	Loss: 0.043450
# Device:3 Trn_Seed - Epoch: 3000 	Loss: 0.044267
#
#
# Device:4 Trn_Seed - Epoch:   0 	Loss: 1.053208
# Device:4 Trn_Seed - Epoch:  50 	Loss: 0.902953
# Device:4 Trn_Seed - Epoch: 100 	Loss: 0.666261
# Device:4 Trn_Seed - Epoch: 150 	Loss: 0.490589
# Device:4 Trn_Seed - Epoch: 200 	Loss: 0.360285
# Device:4 Trn_Seed - Epoch: 250 	Loss: 0.275642
# Device:4 Trn_Seed - Epoch: 300 	Loss: 0.217692
# Device:4 Trn_Seed - Epoch: 350 	Loss: 0.190006
# Device:4 Trn_Seed - Epoch: 400 	Loss: 0.167914
# Device:4 Trn_Seed - Epoch: 450 	Loss: 0.152354
# Device:4 Trn_Seed - Epoch: 500 	Loss: 0.136573
# Device:4 Trn_Seed - Epoch: 550 	Loss: 0.127046
# Device:4 Trn_Seed - Epoch: 600 	Loss: 0.118630
# Device:4 Trn_Seed - Epoch: 650 	Loss: 0.112205
# Device:4 Trn_Seed - Epoch: 700 	Loss: 0.105344
# Device:4 Trn_Seed - Epoch: 750 	Loss: 0.099752
# Device:4 Trn_Seed - Epoch: 800 	Loss: 0.092034
# Device:4 Trn_Seed - Epoch: 850 	Loss: 0.087506
# Device:4 Trn_Seed - Epoch: 900 	Loss: 0.085660
# Device:4 Trn_Seed - Epoch: 950 	Loss: 0.077527
# Device:4 Trn_Seed - Epoch: 1000 	Loss: 0.075301
# Device:4 Trn_Seed - Epoch: 1050 	Loss: 0.075975
# Device:4 Trn_Seed - Epoch: 1100 	Loss: 0.074479
# Device:4 Trn_Seed - Epoch: 1150 	Loss: 0.070194
# Device:4 Trn_Seed - Epoch: 1200 	Loss: 0.067055
# Device:4 Trn_Seed - Epoch: 1250 	Loss: 0.068617
# Device:4 Trn_Seed - Epoch: 1300 	Loss: 0.066679
# Device:4 Trn_Seed - Epoch: 1350 	Loss: 0.063722
# Device:4 Trn_Seed - Epoch: 1400 	Loss: 0.066998
# Device:4 Trn_Seed - Epoch: 1450 	Loss: 0.062912
# Device:4 Trn_Seed - Epoch: 1500 	Loss: 0.060889
# Device:4 Trn_Seed - Epoch: 1550 	Loss: 0.060392
# Device:4 Trn_Seed - Epoch: 1600 	Loss: 0.060425
# Device:4 Trn_Seed - Epoch: 1650 	Loss: 0.060492
# Device:4 Trn_Seed - Epoch: 1700 	Loss: 0.056103
# Device:4 Trn_Seed - Epoch: 1750 	Loss: 0.057182
# Device:4 Trn_Seed - Epoch: 1800 	Loss: 0.057872
# Device:4 Trn_Seed - Epoch: 1850 	Loss: 0.054092
# Device:4 Trn_Seed - Epoch: 1900 	Loss: 0.056696
# Device:4 Trn_Seed - Epoch: 1950 	Loss: 0.055183
# Device:4 Trn_Seed - Epoch: 2000 	Loss: 0.053569
# Device:4 Trn_Seed - Epoch: 2050 	Loss: 0.052418
# Device:4 Trn_Seed - Epoch: 2100 	Loss: 0.054262
# Device:4 Trn_Seed - Epoch: 2150 	Loss: 0.052961
# Device:4 Trn_Seed - Epoch: 2200 	Loss: 0.051767
# Device:4 Trn_Seed - Epoch: 2250 	Loss: 0.050380
# Device:4 Trn_Seed - Epoch: 2300 	Loss: 0.050023
# Device:4 Trn_Seed - Epoch: 2350 	Loss: 0.051522
# Device:4 Trn_Seed - Epoch: 2400 	Loss: 0.050523
# Device:4 Trn_Seed - Epoch: 2450 	Loss: 0.048978
# Device:4 Trn_Seed - Epoch: 2500 	Loss: 0.051560
# Device:4 Trn_Seed - Epoch: 2550 	Loss: 0.048643
# Device:4 Trn_Seed - Epoch: 2600 	Loss: 0.050852
# Device:4 Trn_Seed - Epoch: 2650 	Loss: 0.049172
# Device:4 Trn_Seed - Epoch: 2700 	Loss: 0.047453
# Device:4 Trn_Seed - Epoch: 2750 	Loss: 0.050924
# Device:4 Trn_Seed - Epoch: 2800 	Loss: 0.048537
# Device:4 Trn_Seed - Epoch: 2850 	Loss: 0.049403
# Device:4 Trn_Seed - Epoch: 2900 	Loss: 0.047507
# Device:4 Trn_Seed - Epoch: 2950 	Loss: 0.049510
# Device:4 Trn_Seed - Epoch: 3000 	Loss: 0.046559

# %%
# assign neighbors
for k, v in device_dict.items():
    # full neighbor list
    neighbor_list = [x for x in device_dict.keys() if x != k]
    v.neighbor_list = neighbor_list
    
for k, v in device_dict.items():
    print('D_{}: {}'.format(k, v.neighbor_list))
# Out:
# D_0: [1, 2, 3, 4]
# D_1: [0, 2, 3, 4]
# D_2: [0, 1, 3, 4]
# D_3: [0, 1, 2, 4]
# D_4: [0, 1, 2, 3]

# %%
# overall performance
write_log(log_path, time.ctime(time.time())+' SMLLL')
write_log(log_path, 'AvgAcc\tAvgPre\tAvgRec\tAvgf1')
for rho in range(0,11):
    metric = []
    for k, v in device_dict.items():
        metric.append(v.validate_ensamble(test_loader=loader_dict[k][1], device_dict=device_dict, rho=rho/10))
    metric_arr=np.array(metric)
    log_txt = 'rho = {:.2f}   Avg_acc: {:.4f}'.format(rho/10, np.mean(metric_arr, axis=0)[0])
    print(log_txt)
    write_log(log_path, '{:.4f}\t{:.4f}\t{:.4f}\t{:.4f}'.format(np.mean(metric_arr, axis=0)[0], 
                                                                np.mean(metric_arr, axis=0)[1],
                                                                np.mean(metric_arr, axis=0)[2],
                                                                np.mean(metric_arr, axis=0)[3]))
# Out:
# Device:  0 Val_ensamble - Acc: 1745.0/1800 (0.9694)
# Device:  1 Val_ensamble - Acc: 1749.0/1770 (0.9881)
# Device:  2 Val_ensamble - Acc: 1778.0/1797 (0.9894)
# Device:  3 Val_ensamble - Acc: 1779.0/1799 (0.9889)
# Device:  4 Val_ensamble - Acc: 1790.0/1810 (0.9890)
# rho = 0.00   Avg_acc: 0.9850
# Device:  0 Val_ensamble - Acc: 1748.0/1800 (0.9711)
# Device:  1 Val_ensamble - Acc: 1750.0/1770 (0.9887)
# Device:  2 Val_ensamble - Acc: 1778.0/1797 (0.9894)
# Device:  3 Val_ensamble - Acc: 1777.0/1799 (0.9878)
# Device:  4 Val_ensamble - Acc: 1795.0/1810 (0.9917)
# rho = 0.10   Avg_acc: 0.9857
# Device:  0 Val_ensamble - Acc: 1750.0/1800 (0.9722)
# Device:  1 Val_ensamble - Acc: 1750.0/1770 (0.9887)
# Device:  2 Val_ensamble - Acc: 1781.0/1797 (0.9911)
# Device:  3 Val_ensamble - Acc: 1778.0/1799 (0.9883)
# Device:  4 Val_ensamble - Acc: 1794.0/1810 (0.9912)
# rho = 0.20   Avg_acc: 0.9863
# Device:  0 Val_ensamble - Acc: 1757.0/1800 (0.9761)
# Device:  1 Val_ensamble - Acc: 1753.0/1770 (0.9904)
# Device:  2 Val_ensamble - Acc: 1781.0/1797 (0.9911)
# Device:  3 Val_ensamble - Acc: 1779.0/1799 (0.9889)
# Device:  4 Val_ensamble - Acc: 1792.0/1810 (0.9901)
# rho = 0.30   Avg_acc: 0.9873
# Device:  0 Val_ensamble - Acc: 1759.0/1800 (0.9772)
# Device:  1 Val_ensamble - Acc: 1750.0/1770 (0.9887)
# Device:  2 Val_ensamble - Acc: 1779.0/1797 (0.9900)
# Device:  3 Val_ensamble - Acc: 1780.0/1799 (0.9894)
# Device:  4 Val_ensamble - Acc: 1788.0/1810 (0.9878)
# rho = 0.40   Avg_acc: 0.9866
# Device:  0 Val_ensamble - Acc: 1758.0/1800 (0.9767)
# Device:  1 Val_ensamble - Acc: 1748.0/1770 (0.9876)
# Device:  2 Val_ensamble - Acc: 1777.0/1797 (0.9889)
# Device:  3 Val_ensamble - Acc: 1775.0/1799 (0.9867)
# Device:  4 Val_ensamble - Acc: 1787.0/1810 (0.9873)
# rho = 0.50   Avg_acc: 0.9854
# Device:  0 Val_ensamble - Acc: 1755.0/1800 (0.9750)
# Device:  1 Val_ensamble - Acc: 1749.0/1770 (0.9881)
# Device:  2 Val_ensamble - Acc: 1773.0/1797 (0.9866)
# Device:  3 Val_ensamble - Acc: 1770.0/1799 (0.9839)
# Device:  4 Val_ensamble - Acc: 1782.0/1810 (0.9845)
# rho = 0.60   Avg_acc: 0.9836
# Device:  0 Val_ensamble - Acc: 1751.0/1800 (0.9728)
# Device:  1 Val_ensamble - Acc: 1741.0/1770 (0.9836)
# Device:  2 Val_ensamble - Acc: 1768.0/1797 (0.9839)
# Device:  3 Val_ensamble - Acc: 1766.0/1799 (0.9817)
# Device:  4 Val_ensamble - Acc: 1772.0/1810 (0.9790)
# rho = 0.70   Avg_acc: 0.9802
# Device:  0 Val_ensamble - Acc: 1743.0/1800 (0.9683)
# Device:  1 Val_ensamble - Acc: 1733.0/1770 (0.9791)
# Device:  2 Val_ensamble - Acc: 1758.0/1797 (0.9783)
# Device:  3 Val_ensamble - Acc: 1756.0/1799 (0.9761)
# Device:  4 Val_ensamble - Acc: 1765.0/1810 (0.9751)
# rho = 0.80   Avg_acc: 0.9754
# Device:  0 Val_ensamble - Acc: 1732.0/1800 (0.9622)
# Device:  1 Val_ensamble - Acc: 1724.0/1770 (0.9740)
# Device:  2 Val_ensamble - Acc: 1733.0/1797 (0.9644)
# Device:  3 Val_ensamble - Acc: 1736.0/1799 (0.9650)
# Device:  4 Val_ensamble - Acc: 1746.0/1810 (0.9646)
# rho = 0.90   Avg_acc: 0.9660
# Device:  0 Val_ensamble - Acc: 1710.0/1800 (0.9500)
# Device:  1 Val_ensamble - Acc: 1704.0/1770 (0.9627)
# Device:  2 Val_ensamble - Acc: 1699.0/1797 (0.9455)
# Device:  3 Val_ensamble - Acc: 1709.0/1799 (0.9500)
# Device:  4 Val_ensamble - Acc: 1712.0/1810 (0.9459)
# rho = 1.00   Avg_acc: 0.9508

# %%
# assign neighbors
for k, v in device_dict.items():
    # full neighbor list
    neighbor_list = [x for x in device_dict.keys() if x != k]
    neighbor_list = neighbor_list[:-1]
    if k == 4:
        neighbor_list = []
    v.neighbor_list = neighbor_list
    
for k, v in device_dict.items():
    print('D_{}: {}'.format(k, v.neighbor_list))
# Out:
# D_0: [1, 2, 3]
# D_1: [0, 2, 3]
# D_2: [0, 1, 3]
# D_3: [0, 1, 2]
# D_4: []

# %%
# overall performance
write_log(log_path, time.ctime(time.time())+' SMLL')
write_log(log_path, 'AvgAcc\tAvgPre\tAvgRec\tAvgf1')
for rho in range(0,11):
    metric = []
    for k, v in device_dict.items():
        if k != 4:
            metric.append(v.validate_ensamble(test_loader=loader_dict[k][1], device_dict=device_dict, rho=rho/10))
    metric_arr=np.array(metric)
    log_txt = 'rho = {:.2f}   Avg_acc: {:.4f}'.format(rho/10, np.mean(metric_arr, axis=0)[0])
    print(log_txt)
    write_log(log_path, '{:.4f}\t{:.4f}\t{:.4f}\t{:.4f}'.format(np.mean(metric_arr, axis=0)[0], 
                                                                np.mean(metric_arr, axis=0)[1],
                                                                np.mean(metric_arr, axis=0)[2],
                                                                np.mean(metric_arr, axis=0)[3]))
# Out:
# Device:  0 Val_ensamble - Acc: 1745.0/1800 (0.9694)
# Device:  1 Val_ensamble - Acc: 1749.0/1770 (0.9881)
# Device:  2 Val_ensamble - Acc: 1778.0/1797 (0.9894)
# Device:  3 Val_ensamble - Acc: 1779.0/1799 (0.9889)
# rho = 0.00   Avg_acc: 0.9840
# Device:  0 Val_ensamble - Acc: 1744.0/1800 (0.9689)
# Device:  1 Val_ensamble - Acc: 1751.0/1770 (0.9893)
# Device:  2 Val_ensamble - Acc: 1778.0/1797 (0.9894)
# Device:  3 Val_ensamble - Acc: 1778.0/1799 (0.9883)
# rho = 0.10   Avg_acc: 0.9840
# Device:  0 Val_ensamble - Acc: 1749.0/1800 (0.9717)
# Device:  1 Val_ensamble - Acc: 1750.0/1770 (0.9887)
# Device:  2 Val_ensamble - Acc: 1778.0/1797 (0.9894)
# Device:  3 Val_ensamble - Acc: 1777.0/1799 (0.9878)
# rho = 0.20   Avg_acc: 0.9844
# Device:  0 Val_ensamble - Acc: 1751.0/1800 (0.9728)
# Device:  1 Val_ensamble - Acc: 1749.0/1770 (0.9881)
# Device:  2 Val_ensamble - Acc: 1778.0/1797 (0.9894)
# Device:  3 Val_ensamble - Acc: 1777.0/1799 (0.9878)
# rho = 0.30   Avg_acc: 0.9845
# Device:  0 Val_ensamble - Acc: 1752.0/1800 (0.9733)
# Device:  1 Val_ensamble - Acc: 1748.0/1770 (0.9876)
# Device:  2 Val_ensamble - Acc: 1777.0/1797 (0.9889)
# Device:  3 Val_ensamble - Acc: 1773.0/1799 (0.9855)
# rho = 0.40   Avg_acc: 0.9838
# Device:  0 Val_ensamble - Acc: 1748.0/1800 (0.9711)
# Device:  1 Val_ensamble - Acc: 1750.0/1770 (0.9887)
# Device:  2 Val_ensamble - Acc: 1774.0/1797 (0.9872)
# Device:  3 Val_ensamble - Acc: 1769.0/1799 (0.9833)
# rho = 0.50   Avg_acc: 0.9826
# Device:  0 Val_ensamble - Acc: 1741.0/1800 (0.9672)
# Device:  1 Val_ensamble - Acc: 1743.0/1770 (0.9847)
# Device:  2 Val_ensamble - Acc: 1761.0/1797 (0.9800)
# Device:  3 Val_ensamble - Acc: 1761.0/1799 (0.9789)
# rho = 0.60   Avg_acc: 0.9777
# Device:  0 Val_ensamble - Acc: 1730.0/1800 (0.9611)
# Device:  1 Val_ensamble - Acc: 1738.0/1770 (0.9819)
# Device:  2 Val_ensamble - Acc: 1752.0/1797 (0.9750)
# Device:  3 Val_ensamble - Acc: 1752.0/1799 (0.9739)
# rho = 0.70   Avg_acc: 0.9730
# Device:  0 Val_ensamble - Acc: 1698.0/1800 (0.9433)
# Device:  1 Val_ensamble - Acc: 1725.0/1770 (0.9746)
# Device:  2 Val_ensamble - Acc: 1725.0/1797 (0.9599)
# Device:  3 Val_ensamble - Acc: 1738.0/1799 (0.9661)
# rho = 0.80   Avg_acc: 0.9610
# Device:  0 Val_ensamble - Acc: 1645.0/1800 (0.9139)
# Device:  1 Val_ensamble - Acc: 1706.0/1770 (0.9638)
# Device:  2 Val_ensamble - Acc: 1668.0/1797 (0.9282)
# Device:  3 Val_ensamble - Acc: 1710.0/1799 (0.9505)
# rho = 0.90   Avg_acc: 0.9391
# Device:  0 Val_ensamble - Acc: 1524.0/1800 (0.8467)
# Device:  1 Val_ensamble - Acc: 1650.0/1770 (0.9322)
# Device:  2 Val_ensamble - Acc: 1583.0/1797 (0.8809)
# Device:  3 Val_ensamble - Acc: 1634.0/1799 (0.9083)
# rho = 1.00   Avg_acc: 0.8920

# %%
# assign neighbors
for k, v in device_dict.items():
    # full neighbor list
    neighbor_list = [x for x in device_dict.keys() if x != k]
    neighbor_list = [x for x in neighbor_list if x not in [3,4]]
    if k == 4:
        neighbor_list = []
    if k == 3:
        neighbor_list = []
    v.neighbor_list = neighbor_list
    
for k, v in device_dict.items():
    print('D_{}: {}'.format(k, v.neighbor_list))
# Out:
# D_0: [1, 2]
# D_1: [0, 2]
# D_2: [0, 1]
# D_3: []
# D_4: []

# %%
# overall performance
write_log(log_path, time.ctime(time.time())+' SML')
write_log(log_path, 'AvgAcc\tAvgPre\tAvgRec\tAvgf1')
for rho in range(0,11):
    metric = []
    for k, v in device_dict.items():
        if k not in [3,4]:
            metric.append(v.validate_ensamble(test_loader=loader_dict[k][1], device_dict=device_dict, rho=rho/10))
    metric_arr=np.array(metric)
    log_txt = 'rho = {:.2f}   Avg_acc: {:.4f}'.format(rho/10, np.mean(metric_arr, axis=0)[0])
    print(log_txt)
    write_log(log_path, '{:.4f}\t{:.4f}\t{:.4f}\t{:.4f}'.format(np.mean(metric_arr, axis=0)[0], 
                                                                np.mean(metric_arr, axis=0)[1],
                                                                np.mean(metric_arr, axis=0)[2],
                                                                np.mean(metric_arr, axis=0)[3]))
# Out:
# Device:  0 Val_ensamble - Acc: 1745.0/1800 (0.9694)
# Device:  1 Val_ensamble - Acc: 1749.0/1770 (0.9881)
# Device:  2 Val_ensamble - Acc: 1778.0/1797 (0.9894)
# rho = 0.00   Avg_acc: 0.9823
# Device:  0 Val_ensamble - Acc: 1745.0/1800 (0.9694)
# Device:  1 Val_ensamble - Acc: 1748.0/1770 (0.9876)
# Device:  2 Val_ensamble - Acc: 1778.0/1797 (0.9894)
# rho = 0.10   Avg_acc: 0.9821
# Device:  0 Val_ensamble - Acc: 1745.0/1800 (0.9694)
# Device:  1 Val_ensamble - Acc: 1746.0/1770 (0.9864)
# Device:  2 Val_ensamble - Acc: 1780.0/1797 (0.9905)
# rho = 0.20   Avg_acc: 0.9821
# Device:  0 Val_ensamble - Acc: 1748.0/1800 (0.9711)
# Device:  1 Val_ensamble - Acc: 1743.0/1770 (0.9847)
# Device:  2 Val_ensamble - Acc: 1778.0/1797 (0.9894)
# rho = 0.30   Avg_acc: 0.9818
# Device:  0 Val_ensamble - Acc: 1740.0/1800 (0.9667)
# Device:  1 Val_ensamble - Acc: 1742.0/1770 (0.9842)
# Device:  2 Val_ensamble - Acc: 1779.0/1797 (0.9900)
# rho = 0.40   Avg_acc: 0.9803
# Device:  0 Val_ensamble - Acc: 1735.0/1800 (0.9639)
# Device:  1 Val_ensamble - Acc: 1739.0/1770 (0.9825)
# Device:  2 Val_ensamble - Acc: 1776.0/1797 (0.9883)
# rho = 0.50   Avg_acc: 0.9782
# Device:  0 Val_ensamble - Acc: 1711.0/1800 (0.9506)
# Device:  1 Val_ensamble - Acc: 1729.0/1770 (0.9768)
# Device:  2 Val_ensamble - Acc: 1764.0/1797 (0.9816)
# rho = 0.60   Avg_acc: 0.9697
# Device:  0 Val_ensamble - Acc: 1631.0/1800 (0.9061)
# Device:  1 Val_ensamble - Acc: 1707.0/1770 (0.9644)
# Device:  2 Val_ensamble - Acc: 1715.0/1797 (0.9544)
# rho = 0.70   Avg_acc: 0.9416
# Device:  0 Val_ensamble - Acc: 1454.0/1800 (0.8078)
# Device:  1 Val_ensamble - Acc: 1683.0/1770 (0.9508)
# Device:  2 Val_ensamble - Acc: 1626.0/1797 (0.9048)
# rho = 0.80   Avg_acc: 0.8878
# Device:  0 Val_ensamble - Acc: 1391.0/1800 (0.7728)
# Device:  1 Val_ensamble - Acc: 1616.0/1770 (0.9130)
# Device:  2 Val_ensamble - Acc: 1552.0/1797 (0.8637)
# rho = 0.90   Avg_acc: 0.8498
# Device:  0 Val_ensamble - Acc: 1318.0/1800 (0.7322)
# Device:  1 Val_ensamble - Acc: 1542.0/1770 (0.8712)
# Device:  2 Val_ensamble - Acc: 1511.0/1797 (0.8408)
# rho = 1.00   Avg_acc: 0.8148

# %%
# assign neighbors
for k, v in device_dict.items():
    # full neighbor list
    neighbor_list = [x for x in device_dict.keys() if x != k]
    neighbor_list = [x for x in neighbor_list if x not in [3]]
    if k == 3:
        neighbor_list = []
    v.neighbor_list = neighbor_list
    
for k, v in device_dict.items():
    print('D_{}: {}'.format(k, v.neighbor_list))
# Out:
# D_0: [1, 2, 4]
# D_1: [0, 2, 4]
# D_2: [0, 1, 4]
# D_3: []
# D_4: [0, 1, 2]

# %%
# overall performance
write_log(log_path, time.ctime(time.time())+' SMLL')
write_log(log_path, 'AvgAcc\tAvgPre\tAvgRec\tAvgf1')
for rho in range(0,11):
    metric = []
    for k, v in device_dict.items():
        if k not in [3]:
            metric.append(v.validate_ensamble(test_loader=loader_dict[k][1], device_dict=device_dict, rho=rho/10))
    metric_arr=np.array(metric)
    log_txt = 'rho = {:.2f}   Avg_acc: {:.4f}'.format(rho/10, np.mean(metric_arr, axis=0)[0])
    print(log_txt)
    write_log(log_path, '{:.4f}\t{:.4f}\t{:.4f}\t{:.4f}'.format(np.mean(metric_arr, axis=0)[0], 
                                                                np.mean(metric_arr, axis=0)[1],
                                                                np.mean(metric_arr, axis=0)[2],
                                                                np.mean(metric_arr, axis=0)[3]))
# Out:
# Device:  0 Val_ensamble - Acc: 1745.0/1800 (0.9694)
# Device:  1 Val_ensamble - Acc: 1749.0/1770 (0.9881)
# Device:  2 Val_ensamble - Acc: 1778.0/1797 (0.9894)
# Device:  4 Val_ensamble - Acc: 1790.0/1810 (0.9890)
# rho = 0.00   Avg_acc: 0.9840
# Device:  0 Val_ensamble - Acc: 1750.0/1800 (0.9722)
# Device:  1 Val_ensamble - Acc: 1750.0/1770 (0.9887)
# Device:  2 Val_ensamble - Acc: 1779.0/1797 (0.9900)
# Device:  4 Val_ensamble - Acc: 1794.0/1810 (0.9912)
# rho = 0.10   Avg_acc: 0.9855
# Device:  0 Val_ensamble - Acc: 1755.0/1800 (0.9750)
# Device:  1 Val_ensamble - Acc: 1746.0/1770 (0.9864)
# Device:  2 Val_ensamble - Acc: 1782.0/1797 (0.9917)
# Device:  4 Val_ensamble - Acc: 1793.0/1810 (0.9906)
# rho = 0.20   Avg_acc: 0.9859
# Device:  0 Val_ensamble - Acc: 1756.0/1800 (0.9756)
# Device:  1 Val_ensamble - Acc: 1748.0/1770 (0.9876)
# Device:  2 Val_ensamble - Acc: 1782.0/1797 (0.9917)
# Device:  4 Val_ensamble - Acc: 1791.0/1810 (0.9895)
# rho = 0.30   Avg_acc: 0.9861
# Device:  0 Val_ensamble - Acc: 1756.0/1800 (0.9756)
# Device:  1 Val_ensamble - Acc: 1747.0/1770 (0.9870)
# Device:  2 Val_ensamble - Acc: 1781.0/1797 (0.9911)
# Device:  4 Val_ensamble - Acc: 1788.0/1810 (0.9878)
# rho = 0.40   Avg_acc: 0.9854
# Device:  0 Val_ensamble - Acc: 1753.0/1800 (0.9739)
# Device:  1 Val_ensamble - Acc: 1741.0/1770 (0.9836)
# Device:  2 Val_ensamble - Acc: 1782.0/1797 (0.9917)
# Device:  4 Val_ensamble - Acc: 1781.0/1810 (0.9840)
# rho = 0.50   Avg_acc: 0.9833
# Device:  0 Val_ensamble - Acc: 1748.0/1800 (0.9711)
# Device:  1 Val_ensamble - Acc: 1735.0/1770 (0.9802)
# Device:  2 Val_ensamble - Acc: 1779.0/1797 (0.9900)
# Device:  4 Val_ensamble - Acc: 1776.0/1810 (0.9812)
# rho = 0.60   Avg_acc: 0.9806
# Device:  0 Val_ensamble - Acc: 1734.0/1800 (0.9633)
# Device:  1 Val_ensamble - Acc: 1726.0/1770 (0.9751)
# Device:  2 Val_ensamble - Acc: 1772.0/1797 (0.9861)
# Device:  4 Val_ensamble - Acc: 1766.0/1810 (0.9757)
# rho = 0.70   Avg_acc: 0.9751
# Device:  0 Val_ensamble - Acc: 1722.0/1800 (0.9567)
# Device:  1 Val_ensamble - Acc: 1709.0/1770 (0.9655)
# Device:  2 Val_ensamble - Acc: 1760.0/1797 (0.9794)
# Device:  4 Val_ensamble - Acc: 1747.0/1810 (0.9652)
# rho = 0.80   Avg_acc: 0.9667
# Device:  0 Val_ensamble - Acc: 1693.0/1800 (0.9406)
# Device:  1 Val_ensamble - Acc: 1682.0/1770 (0.9503)
# Device:  2 Val_ensamble - Acc: 1743.0/1797 (0.9699)
# Device:  4 Val_ensamble - Acc: 1726.0/1810 (0.9536)
# rho = 0.90   Avg_acc: 0.9536
# Device:  0 Val_ensamble - Acc: 1642.0/1800 (0.9122)
# Device:  1 Val_ensamble - Acc: 1629.0/1770 (0.9203)
# Device:  2 Val_ensamble - Acc: 1708.0/1797 (0.9505)
# Device:  4 Val_ensamble - Acc: 1653.0/1810 (0.9133)
# rho = 1.00   Avg_acc: 0.9241
