# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Subset, DataLoader
from torchvision import datasets, transforms
import random
import time
import sys

sys.path.append("..")
from utils.tool import GPU_info, write_log, print_label_stat
from models.resnet import ResNet8, ResNet18, ResNet50
from models.mobilenet import MobileNet_S, MobileNet_M, MobileNet_L
from framework.ours import Device
from framework.DSGD import DSGD_Device
from framework.SISA import SISA_Device
from framework.FedAvgUnl import FedAvgServer, FedAvgClient


# one in ['ours', 'DSGD', 'SISA', 'Fed']
Framework = 'DSGD'

# one in ['MNIST', 'FMNIST', 'CIFAR10']
DatasetName = 'MNIST'

# one in ['resnet', 'mobilenet']
ModelType = 'mobilenet'

# one in [1,0]. 1 - Heterogeneous;  0 - Homogeneous
Heterogeneous = 1

# %%
train_set_o = None
test_set_o = None
num_classes = 10
device_num = 6
num_channel = 1
ref_size = 10000
train_test_total_size = int(60000/device_num)
test_ratio = 0.2
CIFAR10_segmentation = 0

train_batch_size = 256 if ModelType == 'resnet' else 32
save_path = './checkpoint'
data_path = '../data'
log_path = '../log/{}_{}_{}.txt'.format(Framework, ModelType, DatasetName)

my_seed = 1
torch.cuda.manual_seed(my_seed)
epoch_num = 100

if DatasetName == 'CIFAR10':
    train_set_o = datasets.CIFAR10(data_path, train=True, download=True)
    test_set_o = datasets.CIFAR10(data_path, train=False, download=True)
    device_num = 5
    num_channel = 3
    epoch_num = 400
    train_test_total_size = int(50000/device_num)
    CIFAR10_segmentation = 1
    

elif DatasetName == 'MNIST':    
    train_set_o = datasets.MNIST(data_path, train=True, download=True)
    test_set_o = datasets.MNIST(data_path, train=False, download=True)
    epoch_num = 200

elif DatasetName == 'FMNIST':    
    train_set_o = datasets.FashionMNIST(data_path, train=True, download=True)
    test_set_o = datasets.FashionMNIST(data_path, train=False, download=True)
    epoch_num = 300

train_set_o.transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,)),
])

test_set_o.transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,)),
])

ref_set = Subset(test_set_o, range(0,int(ref_size)))
ref_loader = torch.utils.data.DataLoader(ref_set, batch_size=train_batch_size,
                                         shuffle=False, num_workers=0)

# %%
# data manipulation
device_dict = {}
loader_dict = {}
print('Device', end='\t')
for class_id in range(num_classes):
    print('Class'+str(class_id), end='\t')
print('SUM')

for device_id in range(device_num):
    range_start = train_test_total_size * device_id
    range_end = range_start + train_test_total_size
    
    # remove one class from each local dataset
    class_to_remove = torch.tensor(device_id%10)
    indices = (torch.tensor(train_set_o.targets[range_start:range_end])[..., None] !=
               class_to_remove).any(-1).nonzero(as_tuple=True)[0]
    
    # split train&test
    train_test_border = int((1-test_ratio)*len(indices))
    train_set = Subset(train_set_o, indices[:train_test_border]+range_start)
    test_set = Subset(train_set_o, indices[train_test_border:]+range_start)
    train_loader = DataLoader(train_set, batch_size=train_batch_size,
                              shuffle=True, num_workers=0)
    test_loader = DataLoader(test_set, batch_size=train_batch_size,
                             shuffle=True, num_workers=0)
    
    loader_dict[device_id] = [train_loader, test_loader]
    print_label_stat(device_id, train_set, num_classes)
    
    
# initialize devices
for device_id in range(device_num):
    gpu_id = 0
    device_dict[device_id] = DSGD_Device(device_id, gpu_id, num_classes, num_channel)
    
    
# assign neighbors
for k, v in device_dict.items():
    # full neighbor list
    neighbor_list = [x for x in device_dict.keys() if x != k]  
    v.neighbor_list = neighbor_list
# Out:
# Device	Class0	Class1	Class2	Class3	Class4	Class5	Class6	Class7	Class8	Class9	SUM
# D-0	0	746	648	681	681	575	673	715	614	663	5996
# D-1	657	0	648	699	641	593	656	699	644	675	5912
# D-2	649	768	0	701	674	582	655	660	631	684	6004
# D-3	655	763	663	0	640	613	682	685	649	668	6018
# D-4	653	758	665	680	0	592	673	675	654	662	6012
# D-5	646	751	681	677	627	0	642	707	675	657	6063

# %%
# heterogenerous scenario 
if Heterogeneous == 1:
    # heterogeneous scenario
    write_log(log_path, 'heterogeneous')
    for k, v in device_dict.items():
        v.model = ResNet8(num_channel) if ModelType == 'resnet' else MobileNet_S(num_channel)
        v.model.cuda(v.gpu_id)
        v.optimizer = optim.Adam(v.model.parameters(), lr=0.01)
else:
    # homogeneous scenario
    write_log(log_path, 'homogeneous')
    for k, v in device_dict.items():
        v.model = ResNet50(num_channel) if ModelType == 'resnet' else MobileNet_L(num_channel)
        v.model.cuda(v.gpu_id)
        v.optimizer = optim.Adam(v.model.parameters(), lr=0.01)

# %%
write_log(log_path, time.ctime(time.time()))
for epoch in range(epoch_num):
    for device_id, device in device_dict.items():
        device.train_local_model(num_iter=3, local_loader=loader_dict[device_id][0])
        device.communication(frac=1, gamma=0.9, device_dict=device_dict)
    metric = []
    for device_id, device in device_dict.items():
        metric.append(device.validate_local_model(test_loader=loader_dict[device_id][1]))
    metric_arr=np.array(metric)
    log_txt = '{:.4f}\t{:.4f}\t{:.4f}\t{:.4f}\t'.format(np.mean(metric_arr, axis=0)[0], 
                                      np.mean(metric_arr, axis=0)[1],np.mean(metric_arr, axis=0)[2],
                                      np.mean(metric_arr, axis=0)[3])
    print('mean: '+ log_txt)
    write_log(log_path, log_txt)
# Out:
# Client 0	Epoch:  0		Loss: 0.94650245
# Client 1	Epoch:  0		Loss: 0.88405657
# Client 2	Epoch:  0		Loss: 0.86257017
# Client 3	Epoch:  0		Loss: 1.80002189
# Client 4	Epoch:  0		Loss: 0.69426745
# Client 5	Epoch:  0		Loss: 0.60473144
# Server - Avg_loss: 0.0834, Acc: 160.0/1499 (0.1067)
# Server - Avg_loss: 0.1006, Acc: 143.0/1479 (0.0967)
# Server - Avg_loss: 0.0805, Acc: 161.0/1501 (0.1073)
# Server - Avg_loss: 0.0919, Acc: 158.0/1505 (0.1050)
# Server - Avg_loss: 0.0798, Acc: 158.0/1504 (0.1051)
# Server - Avg_loss: 0.0887, Acc: 174.0/1516 (0.1148)
# mean: 0.1059	0.0121	0.1109	0.0214
# Client 0	Epoch:  0		Loss: 0.95900005
# Client 1	Epoch:  0		Loss: 0.51814646
# Client 2	Epoch:  0		Loss: 0.38900074
# Client 3	Epoch:  0		Loss: 0.57502472
# Client 4	Epoch:  0		Loss: 0.44001913
# Client 5	Epoch:  0		Loss: 0.33357447
# Server - Avg_loss: 0.1072, Acc: 160.0/1499 (0.1067)
# Server - Avg_loss: 0.1043, Acc: 143.0/1479 (0.0967)
# Server - Avg_loss: 0.0906, Acc: 161.0/1501 (0.1073)
# Server - Avg_loss: 0.1011, Acc: 158.0/1505 (0.1050)
# Server - Avg_loss: 0.0801, Acc: 159.0/1504 (0.1057)
# Server - Avg_loss: 0.0993, Acc: 169.0/1516 (0.1115)
# mean: 0.1055	0.0124	0.1098	0.0213
# Client 0	Epoch:  0		Loss: 0.80379564
# Client 1	Epoch:  0		Loss: 0.51878333
# Client 2	Epoch:  0		Loss: 0.22862864
# Client 3	Epoch:  0		Loss: 1.24429417
# Client 4	Epoch:  0		Loss: 0.16956376
# Client 5	Epoch:  0		Loss: 0.28344491
# Server - Avg_loss: 0.1626, Acc: 155.0/1499 (0.1034)
# Server - Avg_loss: 0.1251, Acc: 143.0/1479 (0.0967)
# Server - Avg_loss: 0.1064, Acc: 162.0/1501 (0.1079)
# Server - Avg_loss: 0.1365, Acc: 146.0/1505 (0.0970)
# Server - Avg_loss: 0.0911, Acc: 179.0/1504 (0.1190)
# Server - Avg_loss: 0.1607, Acc: 169.0/1516 (0.1115)
# mean: 0.1059	0.0136	0.1105	0.0225
# Client 0	Epoch:  0		Loss: 0.20207573
# Client 1	Epoch:  0		Loss: 0.21517448
# Client 2	Epoch:  0		Loss: 0.27357858
# Client 3	Epoch:  0		Loss: 0.24373451
# Client 4	Epoch:  0		Loss: 0.17196153
# Client 5	Epoch:  0		Loss: 0.15363388
# Server - Avg_loss: 0.1933, Acc: 199.0/1499 (0.1328)
# Server - Avg_loss: 0.1428, Acc: 146.0/1479 (0.0987)
# Server - Avg_loss: 0.1228, Acc: 162.0/1501 (0.1079)
# Server - Avg_loss: 0.1830, Acc: 146.0/1505 (0.0970)
# Server - Avg_loss: 0.1742, Acc: 175.0/1504 (0.1164)
# Server - Avg_loss: 0.2023, Acc: 174.0/1516 (0.1148)
# mean: 0.1113	0.0139	0.1099	0.0237
# Client 0	Epoch:  0		Loss: 0.23676057
# Client 1	Epoch:  0		Loss: 0.30333221
# Client 2	Epoch:  0		Loss: 0.04934782
# Client 3	Epoch:  0		Loss: 0.42843062
# Client 4	Epoch:  0		Loss: 0.19616561
# Client 5	Epoch:  0		Loss: 0.42873892
# Server - Avg_loss: 0.2644, Acc: 199.0/1499 (0.1328)
# Server - Avg_loss: 0.1842, Acc: 156.0/1479 (0.1055)
# Server - Avg_loss: 0.1771, Acc: 162.0/1501 (0.1079)
# Server - Avg_loss: 0.2286, Acc: 146.0/1505 (0.0970)
# Server - Avg_loss: 0.1866, Acc: 190.0/1504 (0.1263)
# Server - Avg_loss: 0.2575, Acc: 170.0/1516 (0.1121)
# mean: 0.1136	0.0129	0.1110	0.0227
# Client 0	Epoch:  0		Loss: 0.17531686
# Client 1	Epoch:  0		Loss: 0.22079331
# Client 2	Epoch:  0		Loss: 0.12727401
# Client 3	Epoch:  0		Loss: 0.15196365
# Client 4	Epoch:  0		Loss: 0.18727776
# Client 5	Epoch:  0		Loss: 0.12928472
# Server - Avg_loss: 0.3386, Acc: 199.0/1499 (0.1328)
# Server - Avg_loss: 0.2567, Acc: 156.0/1479 (0.1055)
# Server - Avg_loss: 0.1901, Acc: 162.0/1501 (0.1079)
# Server - Avg_loss: 0.3214, Acc: 146.0/1505 (0.0970)
# Server - Avg_loss: 0.2362, Acc: 125.0/1504 (0.0831)
# Server - Avg_loss: 0.2883, Acc: 170.0/1516 (0.1121)
# mean: 0.1064	0.0137	0.1031	0.0234
# Client 0	Epoch:  0		Loss: 0.06432410
# Client 1	Epoch:  0		Loss: 0.40839633
# Client 2	Epoch:  0		Loss: 0.16946003
# Client 3	Epoch:  0		Loss: 1.61426985
# Client 4	Epoch:  0		Loss: 0.08394083
# Client 5	Epoch:  0		Loss: 0.22201163
# Server - Avg_loss: 0.3880, Acc: 199.0/1499 (0.1328)
# Server - Avg_loss: 0.2372, Acc: 176.0/1479 (0.1190)
# Server - Avg_loss: 0.2473, Acc: 191.0/1501 (0.1272)
# Server - Avg_loss: 0.3076, Acc: 146.0/1505 (0.0970)
# Server - Avg_loss: 0.3178, Acc: 184.0/1504 (0.1223)
# Server - Avg_loss: 0.3261, Acc: 170.0/1516 (0.1121)
# mean: 0.1184	0.0211	0.1150	0.0273
# Client 0	Epoch:  0		Loss: 0.07440148
# Client 1	Epoch:  0		Loss: 0.19999804
# Client 2	Epoch:  0		Loss: 0.10118698
# Client 3	Epoch:  0		Loss: 0.20506741
# Client 4	Epoch:  0		Loss: 0.07455488
# Client 5	Epoch:  0		Loss: 0.39469406
# Server - Avg_loss: 0.3744, Acc: 199.0/1499 (0.1328)
# Server - Avg_loss: 0.2615, Acc: 176.0/1479 (0.1190)
# Server - Avg_loss: 0.1947, Acc: 194.0/1501 (0.1292)
# Server - Avg_loss: 0.3180, Acc: 146.0/1505 (0.0970)
# Server - Avg_loss: 0.3293, Acc: 190.0/1504 (0.1263)
# Server - Avg_loss: 0.3484, Acc: 170.0/1516 (0.1121)
# mean: 0.1194	0.0136	0.1109	0.0237
# Client 0	Epoch:  0		Loss: 0.10405904
# Client 1	Epoch:  0		Loss: 0.11264522
# Client 2	Epoch:  0		Loss: 0.17855854
# Client 3	Epoch:  0		Loss: 0.20052812
# Client 4	Epoch:  0		Loss: 0.10639764
# Client 5	Epoch:  0		Loss: 0.08372930
# Server - Avg_loss: 0.3450, Acc: 79.0/1499 (0.0527)
# Server - Avg_loss: 0.3183, Acc: 176.0/1479 (0.1190)
# Server - Avg_loss: 0.2826, Acc: 194.0/1501 (0.1292)
# Server - Avg_loss: 0.3025, Acc: 146.0/1505 (0.0970)
# Server - Avg_loss: 0.3855, Acc: 175.0/1504 (0.1164)
# Server - Avg_loss: 0.4335, Acc: 170.0/1516 (0.1121)
# mean: 0.1044	0.0138	0.1011	0.0233
# Client 0	Epoch:  0		Loss: 0.37347463
# Client 1	Epoch:  0		Loss: 0.05107670
# Client 2	Epoch:  0		Loss: 0.06174069
# Client 3	Epoch:  0		Loss: 0.61509883
# Client 4	Epoch:  0		Loss: 0.09719975
# Client 5	Epoch:  0		Loss: 0.09074643
# Server - Avg_loss: 0.3602, Acc: 199.0/1499 (0.1328)
# Server - Avg_loss: 0.2563, Acc: 222.0/1479 (0.1501)
# Server - Avg_loss: 0.2955, Acc: 194.0/1501 (0.1292)
# Server - Avg_loss: 0.2297, Acc: 146.0/1505 (0.0970)
# Server - Avg_loss: 0.3484, Acc: 190.0/1504 (0.1263)
# Server - Avg_loss: 0.4209, Acc: 170.0/1516 (0.1121)
# mean: 0.1246	0.0170	0.1169	0.0285
# Client 0	Epoch:  0		Loss: 0.12145647
# Client 1	Epoch:  0		Loss: 0.24717249
# Client 2	Epoch:  0		Loss: 0.31418321
# Client 3	Epoch:  0		Loss: 0.16125640
# Client 4	Epoch:  0		Loss: 0.44866419
# Client 5	Epoch:  0		Loss: 0.24066228
# Server - Avg_loss: 0.3700, Acc: 199.0/1499 (0.1328)
# Server - Avg_loss: 0.2783, Acc: 176.0/1479 (0.1190)
# Server - Avg_loss: 0.3237, Acc: 194.0/1501 (0.1292)
# Server - Avg_loss: 0.2654, Acc: 146.0/1505 (0.0970)
# Server - Avg_loss: 0.4071, Acc: 190.0/1504 (0.1263)
# Server - Avg_loss: 0.3851, Acc: 166.0/1516 (0.1095)
# mean: 0.1190	0.0138	0.1126	0.0240
# Client 0	Epoch:  0		Loss: 0.11755659
# Client 1	Epoch:  0		Loss: 0.20369302
# Client 2	Epoch:  0		Loss: 0.22152114
# Client 3	Epoch:  0		Loss: 2.02763605
# Client 4	Epoch:  0		Loss: 0.15009268
# Client 5	Epoch:  0		Loss: 0.49384180
# Server - Avg_loss: 0.3930, Acc: 257.0/1499 (0.1714)
# Server - Avg_loss: 0.2983, Acc: 176.0/1479 (0.1190)
# Server - Avg_loss: 0.3613, Acc: 194.0/1501 (0.1292)
# Server - Avg_loss: 0.2322, Acc: 422.0/1505 (0.2804)
# Server - Avg_loss: 0.3363, Acc: 193.0/1504 (0.1283)
# Server - Avg_loss: 0.4299, Acc: 170.0/1516 (0.1121)
# mean: 0.1568	0.0446	0.1441	0.0553
# Client 0	Epoch:  0		Loss: 0.09641663
# Client 1	Epoch:  0		Loss: 0.11848845
# Client 2	Epoch:  0		Loss: 0.05522292
# Client 3	Epoch:  0		Loss: 0.01778212
# Client 4	Epoch:  0		Loss: 0.19150022
# Client 5	Epoch:  0		Loss: 0.08556835
# Server - Avg_loss: 0.4362, Acc: 333.0/1499 (0.2221)
# Server - Avg_loss: 0.3170, Acc: 176.0/1479 (0.1190)
# Server - Avg_loss: 0.3626, Acc: 177.0/1501 (0.1179)
# Server - Avg_loss: 0.3424, Acc: 165.0/1505 (0.1096)
# Server - Avg_loss: 0.3687, Acc: 192.0/1504 (0.1277)
# Server - Avg_loss: 0.3861, Acc: 170.0/1516 (0.1121)
# mean: 0.1348	0.0281	0.1263	0.0410
# Client 0	Epoch:  0		Loss: 0.15973535
# Client 1	Epoch:  0		Loss: 0.14678608
# Client 2	Epoch:  0		Loss: 0.37110871
# Client 3	Epoch:  0		Loss: 0.86367428
# Client 4	Epoch:  0		Loss: 0.27138278
# Client 5	Epoch:  0		Loss: 0.20637122
# Server - Avg_loss: 0.4412, Acc: 199.0/1499 (0.1328)
# Server - Avg_loss: 0.3764, Acc: 156.0/1479 (0.1055)
# Server - Avg_loss: 0.4549, Acc: 177.0/1501 (0.1179)
# Server - Avg_loss: 0.3318, Acc: 170.0/1505 (0.1130)
# Server - Avg_loss: 0.3944, Acc: 209.0/1504 (0.1390)
# Server - Avg_loss: 0.4713, Acc: 166.0/1516 (0.1095)
# mean: 0.1196	0.0170	0.1154	0.0283
# Client 0	Epoch:  0		Loss: 0.11744978
# Client 1	Epoch:  0		Loss: 0.07090526
# Client 2	Epoch:  0		Loss: 0.05326309
# Client 3	Epoch:  0		Loss: 0.55002320
# Client 4	Epoch:  0		Loss: 0.09626806
# Client 5	Epoch:  0		Loss: 0.34708682
# Server - Avg_loss: 0.4130, Acc: 199.0/1499 (0.1328)
# Server - Avg_loss: 0.3927, Acc: 156.0/1479 (0.1055)
# Server - Avg_loss: 0.3691, Acc: 339.0/1501 (0.2258)
# Server - Avg_loss: 0.3221, Acc: 199.0/1505 (0.1322)
# Server - Avg_loss: 0.4007, Acc: 185.0/1504 (0.1230)
# Server - Avg_loss: 0.4751, Acc: 166.0/1516 (0.1095)
# mean: 0.1381	0.0284	0.1348	0.0404
# Client 0	Epoch:  0		Loss: 0.07398232
# Client 1	Epoch:  0		Loss: 0.31012046
# Client 2	Epoch:  0		Loss: 0.34553576
# Client 3	Epoch:  0		Loss: 0.00193233
# Client 4	Epoch:  0		Loss: 0.09379441
# Client 5	Epoch:  0		Loss: 0.09410806
# Server - Avg_loss: 0.3809, Acc: 304.0/1499 (0.2028)
# Server - Avg_loss: 0.4371, Acc: 156.0/1479 (0.1055)
# Server - Avg_loss: 0.4557, Acc: 177.0/1501 (0.1179)
# Server - Avg_loss: 0.3224, Acc: 262.0/1505 (0.1741)
# Server - Avg_loss: 0.4117, Acc: 334.0/1504 (0.2221)
# Server - Avg_loss: 0.4353, Acc: 166.0/1516 (0.1095)
# mean: 0.1553	0.0546	0.1481	0.0613
# Client 0	Epoch:  0		Loss: 0.38030398
# Client 1	Epoch:  0		Loss: 0.07640021
# Client 2	Epoch:  0		Loss: 0.21259353
# Client 3	Epoch:  0		Loss: 1.21963668
# Client 4	Epoch:  0		Loss: 0.02521729
# Client 5	Epoch:  0		Loss: 0.31913587
# Server - Avg_loss: 0.4316, Acc: 199.0/1499 (0.1328)
# Server - Avg_loss: 0.4769, Acc: 176.0/1479 (0.1190)
# Server - Avg_loss: 0.4837, Acc: 194.0/1501 (0.1292)
# Server - Avg_loss: 0.2764, Acc: 241.0/1505 (0.1601)
# Server - Avg_loss: 0.4247, Acc: 283.0/1504 (0.1882)
# Server - Avg_loss: 0.4685, Acc: 232.0/1516 (0.1530)
# mean: 0.1471	0.0408	0.1389	0.0478
# Client 0	Epoch:  0		Loss: 0.06807377
# Client 1	Epoch:  0		Loss: 0.24164794
# Client 2	Epoch:  0		Loss: 0.13680916
# Client 3	Epoch:  0		Loss: 1.12768924
# Client 4	Epoch:  0		Loss: 0.12278841
# Client 5	Epoch:  0		Loss: 0.12390569
# Server - Avg_loss: 0.3986, Acc: 269.0/1499 (0.1795)
# Server - Avg_loss: 0.4796, Acc: 176.0/1479 (0.1190)
# Server - Avg_loss: 0.4611, Acc: 288.0/1501 (0.1919)
# Server - Avg_loss: 0.3036, Acc: 146.0/1505 (0.0970)
# Server - Avg_loss: 0.5142, Acc: 175.0/1504 (0.1164)
# Server - Avg_loss: 0.4763, Acc: 174.0/1516 (0.1148)
# mean: 0.1364	0.0243	0.1280	0.0385
# Client 0	Epoch:  0		Loss: 0.13539045
# Client 1	Epoch:  0		Loss: 0.16232757
# Client 2	Epoch:  0		Loss: 0.19807717
# Client 3	Epoch:  0		Loss: 1.27288258
# Client 4	Epoch:  0		Loss: 0.11505068
# Client 5	Epoch:  0		Loss: 0.42141575
# Server - Avg_loss: 0.3790, Acc: 208.0/1499 (0.1388)
# Server - Avg_loss: 0.4577, Acc: 176.0/1479 (0.1190)
# Server - Avg_loss: 0.4093, Acc: 194.0/1501 (0.1292)
# Server - Avg_loss: 0.2938, Acc: 293.0/1505 (0.1947)
# Server - Avg_loss: 0.4001, Acc: 210.0/1504 (0.1396)
# Server - Avg_loss: 0.5108, Acc: 174.0/1516 (0.1148)
# mean: 0.1393	0.0426	0.1299	0.0461
# Client 0	Epoch:  0		Loss: 0.83779663
# Client 1	Epoch:  0		Loss: 0.24607909
# Client 2	Epoch:  0		Loss: 0.07810003
# Client 3	Epoch:  0		Loss: 0.39890888
# Client 4	Epoch:  0		Loss: 0.18837373
# Client 5	Epoch:  0		Loss: 0.22813679
# Server - Avg_loss: 0.3933, Acc: 262.0/1499 (0.1748)
# Server - Avg_loss: 0.3924, Acc: 176.0/1479 (0.1190)
# Server - Avg_loss: 0.4167, Acc: 194.0/1501 (0.1292)
# Server - Avg_loss: 0.2959, Acc: 170.0/1505 (0.1130)
# Server - Avg_loss: 0.4458, Acc: 175.0/1504 (0.1164)
# Server - Avg_loss: 0.4821, Acc: 174.0/1516 (0.1148)
# mean: 0.1279	0.0283	0.1185	0.0341
# Client 0	Epoch:  0		Loss: 0.03754205
# Client 1	Epoch:  0		Loss: 0.15799484
# Client 2	Epoch:  0		Loss: 0.09620389
# Client 3	Epoch:  0		Loss: 0.09284664
# Client 4	Epoch:  0		Loss: 0.09566794
# Client 5	Epoch:  0		Loss: 0.95690227
# Server - Avg_loss: 0.3515, Acc: 199.0/1499 (0.1328)
# Server - Avg_loss: 0.4523, Acc: 144.0/1479 (0.0974)
# Server - Avg_loss: 0.3744, Acc: 285.0/1501 (0.1899)
# Server - Avg_loss: 0.2727, Acc: 316.0/1505 (0.2100)
# Server - Avg_loss: 0.3642, Acc: 181.0/1504 (0.1203)
# Server - Avg_loss: 0.4636, Acc: 174.0/1516 (0.1148)
# mean: 0.1442	0.0289	0.1359	0.0413
# Client 0	Epoch:  0		Loss: 0.03854505
# Client 1	Epoch:  0		Loss: 0.12160462
# Client 2	Epoch:  0		Loss: 0.03735182
# Client 3	Epoch:  0		Loss: 0.92095917
# Client 4	Epoch:  0		Loss: 0.09269749
# Client 5	Epoch:  0		Loss: 0.06184778
# Server - Avg_loss: 0.3569, Acc: 199.0/1499 (0.1328)
# Server - Avg_loss: 0.4582, Acc: 210.0/1479 (0.1420)
# Server - Avg_loss: 0.4109, Acc: 210.0/1501 (0.1399)
# Server - Avg_loss: 0.2589, Acc: 362.0/1505 (0.2405)
# Server - Avg_loss: 0.3851, Acc: 175.0/1504 (0.1164)
# Server - Avg_loss: 0.4930, Acc: 174.0/1516 (0.1148)
# mean: 0.1477	0.0353	0.1348	0.0457
# Client 0	Epoch:  0		Loss: 0.02885814
# Client 1	Epoch:  0		Loss: 0.05695556
# Client 2	Epoch:  0		Loss: 0.03597213
# Client 3	Epoch:  0		Loss: 0.08512154
# Client 4	Epoch:  0		Loss: 0.11252493
# Client 5	Epoch:  0		Loss: 0.50902271
# Server - Avg_loss: 0.2583, Acc: 202.0/1499 (0.1348)
# Server - Avg_loss: 0.4032, Acc: 261.0/1479 (0.1765)
# Server - Avg_loss: 0.3022, Acc: 207.0/1501 (0.1379)
# Server - Avg_loss: 0.2654, Acc: 336.0/1505 (0.2233)
# Server - Avg_loss: 0.4164, Acc: 286.0/1504 (0.1902)
# Server - Avg_loss: 0.4930, Acc: 174.0/1516 (0.1148)
# mean: 0.1629	0.0453	0.1526	0.0580
# Client 0	Epoch:  0		Loss: 0.05420519
# Client 1	Epoch:  0		Loss: 0.27676764
# Client 2	Epoch:  0		Loss: 0.01655857
# Client 3	Epoch:  0		Loss: 2.12157774
# Client 4	Epoch:  0		Loss: 0.13124654
# Client 5	Epoch:  0		Loss: 0.06079416
# Server - Avg_loss: 0.2757, Acc: 246.0/1499 (0.1641)
# Server - Avg_loss: 0.4118, Acc: 274.0/1479 (0.1853)
# Server - Avg_loss: 0.2738, Acc: 270.0/1501 (0.1799)
# Server - Avg_loss: 0.2837, Acc: 333.0/1505 (0.2213)
# Server - Avg_loss: 0.4199, Acc: 198.0/1504 (0.1316)
# Server - Avg_loss: 0.4185, Acc: 174.0/1516 (0.1148)
# mean: 0.1662	0.0523	0.1589	0.0639
# Client 0	Epoch:  0		Loss: 0.11316202
# Client 1	Epoch:  0		Loss: 0.12780207
# Client 2	Epoch:  0		Loss: 0.06649983
# Client 3	Epoch:  0		Loss: 0.57998437
# Client 4	Epoch:  0		Loss: 0.17804480
# Client 5	Epoch:  0		Loss: 0.11005409
# Server - Avg_loss: 0.2392, Acc: 177.0/1499 (0.1181)
# Server - Avg_loss: 0.4036, Acc: 176.0/1479 (0.1190)
# Server - Avg_loss: 0.2789, Acc: 364.0/1501 (0.2425)
# Server - Avg_loss: 0.2388, Acc: 286.0/1505 (0.1900)
# Server - Avg_loss: 0.4231, Acc: 175.0/1504 (0.1164)
# Server - Avg_loss: 0.3705, Acc: 182.0/1516 (0.1201)
# mean: 0.1510	0.0296	0.1465	0.0458
# Client 0	Epoch:  0		Loss: 0.39291081
# Client 1	Epoch:  0		Loss: 0.12934254
# Client 2	Epoch:  0		Loss: 0.08752999
# Client 3	Epoch:  0		Loss: 0.06773952
# Client 4	Epoch:  0		Loss: 0.11604578
# Client 5	Epoch:  0		Loss: 0.10252673
# Server - Avg_loss: 0.2560, Acc: 177.0/1499 (0.1181)
# Server - Avg_loss: 0.3628, Acc: 273.0/1479 (0.1846)
# Server - Avg_loss: 0.2984, Acc: 326.0/1501 (0.2172)
# Server - Avg_loss: 0.2343, Acc: 338.0/1505 (0.2246)
# Server - Avg_loss: 0.4071, Acc: 175.0/1504 (0.1164)
# Server - Avg_loss: 0.3444, Acc: 158.0/1516 (0.1042)
# mean: 0.1608	0.0360	0.1504	0.0528
# Client 0	Epoch:  0		Loss: 0.31753969
# Client 1	Epoch:  0		Loss: 0.08772460
# Client 2	Epoch:  0		Loss: 0.28681469
# Client 3	Epoch:  0		Loss: 1.65357840
# Client 4	Epoch:  0		Loss: 0.23579454
# Client 5	Epoch:  0		Loss: 0.07658236
# Server - Avg_loss: 0.2000, Acc: 177.0/1499 (0.1181)
# Server - Avg_loss: 0.3823, Acc: 301.0/1479 (0.2035)
# Server - Avg_loss: 0.2765, Acc: 204.0/1501 (0.1359)
# Server - Avg_loss: 0.3099, Acc: 282.0/1505 (0.1874)
# Server - Avg_loss: 0.3748, Acc: 187.0/1504 (0.1243)
# Server - Avg_loss: 0.3327, Acc: 166.0/1516 (0.1095)
# mean: 0.1465	0.0401	0.1438	0.0472
# Client 0	Epoch:  0		Loss: 0.12920719
# Client 1	Epoch:  0		Loss: 0.33462644
# Client 2	Epoch:  0		Loss: 0.07090884
# Client 3	Epoch:  0		Loss: 1.32009232
# Client 4	Epoch:  0		Loss: 0.17688850
# Client 5	Epoch:  0		Loss: 0.56507242
# Server - Avg_loss: 0.2242, Acc: 75.0/1499 (0.0500)
# Server - Avg_loss: 0.3533, Acc: 293.0/1479 (0.1981)
# Server - Avg_loss: 0.3244, Acc: 177.0/1501 (0.1179)
# Server - Avg_loss: 0.2854, Acc: 315.0/1505 (0.2093)
# Server - Avg_loss: 0.4002, Acc: 183.0/1504 (0.1217)
# Server - Avg_loss: 0.3057, Acc: 166.0/1516 (0.1095)
# mean: 0.1344	0.0370	0.1301	0.0475
# Client 0	Epoch:  0		Loss: 0.11153584
# Client 1	Epoch:  0		Loss: 0.04331717
# Client 2	Epoch:  0		Loss: 0.08512389
# Client 3	Epoch:  0		Loss: 1.79983115
# Client 4	Epoch:  0		Loss: 0.08631770
# Client 5	Epoch:  0		Loss: 0.04827728
# Server - Avg_loss: 0.1984, Acc: 365.0/1499 (0.2435)
# Server - Avg_loss: 0.3923, Acc: 251.0/1479 (0.1697)
# Server - Avg_loss: 0.3070, Acc: 177.0/1501 (0.1179)
# Server - Avg_loss: 0.3007, Acc: 175.0/1505 (0.1163)
# Server - Avg_loss: 0.4166, Acc: 179.0/1504 (0.1190)
# Server - Avg_loss: 0.3294, Acc: 166.0/1516 (0.1095)
# mean: 0.1460	0.0311	0.1382	0.0444
# Client 0	Epoch:  0		Loss: 0.02933557
# Client 1	Epoch:  0		Loss: 0.09209902
# Client 2	Epoch:  0		Loss: 0.06416561
# Client 3	Epoch:  0		Loss: 0.01941312
# Client 4	Epoch:  0		Loss: 0.20769314
# Client 5	Epoch:  0		Loss: 0.19593011
# Server - Avg_loss: 0.1607, Acc: 342.0/1499 (0.2282)
# Server - Avg_loss: 0.3654, Acc: 205.0/1479 (0.1386)
# Server - Avg_loss: 0.3078, Acc: 178.0/1501 (0.1186)
# Server - Avg_loss: 0.2812, Acc: 298.0/1505 (0.1980)
# Server - Avg_loss: 0.3529, Acc: 180.0/1504 (0.1197)
# Server - Avg_loss: 0.3171, Acc: 166.0/1516 (0.1095)
# mean: 0.1521	0.0467	0.1484	0.0552
# Client 0	Epoch:  0		Loss: 0.04646258
# Client 1	Epoch:  0		Loss: 0.04637934
# Client 2	Epoch:  0		Loss: 0.47367841
# Client 3	Epoch:  0		Loss: 0.28427440
# Client 4	Epoch:  0		Loss: 0.18166234
# Client 5	Epoch:  0		Loss: 0.06352603
# Server - Avg_loss: 0.2089, Acc: 187.0/1499 (0.1247)
# Server - Avg_loss: 0.3791, Acc: 283.0/1479 (0.1913)
# Server - Avg_loss: 0.2592, Acc: 192.0/1501 (0.1279)
# Server - Avg_loss: 0.2697, Acc: 277.0/1505 (0.1841)
# Server - Avg_loss: 0.3457, Acc: 175.0/1504 (0.1164)
# Server - Avg_loss: 0.3196, Acc: 166.0/1516 (0.1095)
# mean: 0.1423	0.0335	0.1375	0.0445
# Client 0	Epoch:  0		Loss: 0.09412730
# Client 1	Epoch:  0		Loss: 0.05553949
# Client 2	Epoch:  0		Loss: 0.05175256
# Client 3	Epoch:  0		Loss: 0.09642640
# Client 4	Epoch:  0		Loss: 0.11982531
# Client 5	Epoch:  0		Loss: 0.35685402
# Server - Avg_loss: 0.1673, Acc: 209.0/1499 (0.1394)
# Server - Avg_loss: 0.3541, Acc: 236.0/1479 (0.1596)
# Server - Avg_loss: 0.2243, Acc: 280.0/1501 (0.1865)
# Server - Avg_loss: 0.2661, Acc: 171.0/1505 (0.1136)
# Server - Avg_loss: 0.2600, Acc: 210.0/1504 (0.1396)
# Server - Avg_loss: 0.2866, Acc: 166.0/1516 (0.1095)
# mean: 0.1414	0.0413	0.1369	0.0487
# Client 0	Epoch:  0		Loss: 0.00860763
# Client 1	Epoch:  0		Loss: 0.06345025
# Client 2	Epoch:  0		Loss: 0.08474092
# Client 3	Epoch:  0		Loss: 0.72809356
# Client 4	Epoch:  0		Loss: 0.05543120
# Client 5	Epoch:  0		Loss: 0.16774444
# Server - Avg_loss: 0.1901, Acc: 179.0/1499 (0.1194)
# Server - Avg_loss: 0.3286, Acc: 290.0/1479 (0.1961)
# Server - Avg_loss: 0.2730, Acc: 177.0/1501 (0.1179)
# Server - Avg_loss: 0.1931, Acc: 431.0/1505 (0.2864)
# Server - Avg_loss: 0.2489, Acc: 203.0/1504 (0.1350)
# Server - Avg_loss: 0.2793, Acc: 164.0/1516 (0.1082)
# mean: 0.1605	0.0466	0.1542	0.0591
# Client 0	Epoch:  0		Loss: 0.10146507
# Client 1	Epoch:  0		Loss: 0.44229993
# Client 2	Epoch:  0		Loss: 0.00461610
# Client 3	Epoch:  0		Loss: 1.63033438
# Client 4	Epoch:  0		Loss: 0.07358362
# Client 5	Epoch:  0		Loss: 0.04453052
# Server - Avg_loss: 0.2644, Acc: 177.0/1499 (0.1181)
# Server - Avg_loss: 0.2866, Acc: 205.0/1479 (0.1386)
# Server - Avg_loss: 0.2227, Acc: 176.0/1501 (0.1173)
# Server - Avg_loss: 0.2635, Acc: 231.0/1505 (0.1535)
# Server - Avg_loss: 0.2647, Acc: 183.0/1504 (0.1217)
# Server - Avg_loss: 0.3025, Acc: 166.0/1516 (0.1095)
# mean: 0.1264	0.0246	0.1245	0.0358
# Client 0	Epoch:  0		Loss: 0.02903065
# Client 1	Epoch:  0		Loss: 0.08060234
# Client 2	Epoch:  0		Loss: 0.01084618
# Client 3	Epoch:  0		Loss: 4.13029099
# Client 4	Epoch:  0		Loss: 0.01967731
# Client 5	Epoch:  0		Loss: 0.01791773
# Server - Avg_loss: 0.1782, Acc: 248.0/1499 (0.1654)
# Server - Avg_loss: 0.3448, Acc: 169.0/1479 (0.1143)
# Server - Avg_loss: 0.1973, Acc: 228.0/1501 (0.1519)
# Server - Avg_loss: 0.2457, Acc: 171.0/1505 (0.1136)
# Server - Avg_loss: 0.2426, Acc: 469.0/1504 (0.3118)
# Server - Avg_loss: 0.3010, Acc: 235.0/1516 (0.1550)
# mean: 0.1687	0.0554	0.1605	0.0665
# Client 0	Epoch:  0		Loss: 0.16279401
# Client 1	Epoch:  0		Loss: 0.02162107
# Client 2	Epoch:  0		Loss: 0.04755469
# Client 3	Epoch:  0		Loss: 0.47230405
# Client 4	Epoch:  0		Loss: 0.03676575
# Client 5	Epoch:  0		Loss: 0.01810583
# Server - Avg_loss: 0.2055, Acc: 201.0/1499 (0.1341)
# Server - Avg_loss: 0.3177, Acc: 170.0/1479 (0.1149)
# Server - Avg_loss: 0.2030, Acc: 210.0/1501 (0.1399)
# Server - Avg_loss: 0.2661, Acc: 181.0/1505 (0.1203)
# Server - Avg_loss: 0.2836, Acc: 283.0/1504 (0.1882)
# Server - Avg_loss: 0.3005, Acc: 191.0/1516 (0.1260)
# mean: 0.1372	0.0378	0.1312	0.0444
# Client 0	Epoch:  0		Loss: 0.02408122
# Client 1	Epoch:  0		Loss: 0.02870996
# Client 2	Epoch:  0		Loss: 0.01880125
# Client 3	Epoch:  0		Loss: 0.29894394
# Client 4	Epoch:  0		Loss: 0.02137995
# Client 5	Epoch:  0		Loss: 0.06691184
# Server - Avg_loss: 0.2429, Acc: 179.0/1499 (0.1194)
# Server - Avg_loss: 0.2428, Acc: 177.0/1479 (0.1197)
# Server - Avg_loss: 0.2459, Acc: 177.0/1501 (0.1179)
# Server - Avg_loss: 0.3030, Acc: 170.0/1505 (0.1130)
# Server - Avg_loss: 0.2954, Acc: 177.0/1504 (0.1177)
# Server - Avg_loss: 0.2925, Acc: 168.0/1516 (0.1108)
# mean: 0.1164	0.0174	0.1118	0.0260

# %%
# write_log(log_path, time.ctime(time.time()))
for epoch in range(epoch_num):
    for device_id, device in device_dict.items():
        device.train_local_model(num_iter=3, local_loader=loader_dict[device_id][0])
        device.communication(frac=1, gamma=0.9, device_dict=device_dict)
    metric = []
    for device_id, device in device_dict.items():
        metric.append(device.validate_local_model(test_loader=loader_dict[device_id][1]))
    metric_arr=np.array(metric)
    log_txt = '{:.4f}\t{:.4f}\t{:.4f}\t{:.4f}\t'.format(np.mean(metric_arr, axis=0)[0], 
                                      np.mean(metric_arr, axis=0)[1],np.mean(metric_arr, axis=0)[2],
                                      np.mean(metric_arr, axis=0)[3])
    print('mean: '+ log_txt)
    write_log(log_path, log_txt)
